# %% [markdown]
# # Preliminaries

# %%
import pandas as pd  #importing all the important packages
import numpy as np
import matplotlib.pyplot as plt #currently not used
import seaborn as sns #currently not used
import pickle

# %% [markdown]
# Import the table containing pokedex pokemon data for generation 5.

# %%
pickle_in = open('gen5_pokemon.pickle','rb')
pokemon = pickle.load(pickle_in)

# %% [markdown]
# Import the table containing all moves data for each pokemon in generation 5.

# %%
pickle_in = open('all_gen5_moves.pickle','rb')
moves = pickle.load(pickle_in)

# %% [markdown]
# We can import functions from other .ipynb files using:

# %%
from ipynb.fs.defs.Functions import type_weakness,dmg,base_stats_at_lvl,phys_spec_ratio,get_moves,battle,battle_list,speed_test,move_effectiveness,pokemon_effectiveness

# %%
battle_list('Gurdurr',31,'Palpitoad',29,['Rock Throw','Wake-up Slap'],False,pokemon,moves)
# Out:
# Rock Throw [14, 18]
# Wake-up Slap [54, 64]

# %%
#moves with no power
l = moves[moves['POWER']=='??']
l = l.drop(['POKEMON','LVL'], axis=1)
l = l.drop_duplicates(keep='first')
l
# Out:
#                   TYPE  CATEGORY POWER ACCURACY  PP EFF %  \
# MOVE
# Wring Out       normal   special    ??      100   5    --
# Hidden Power    normal   special    ??      100  15    --
# Frustration     normal  physical    ??      100  20    --
# Return          normal  physical    ??      100  20    --
# Grass Knot       grass   special    ??      100  20    --
# Natural Gift    normal  physical    ??      100  15    --
# Mirror Coat    psychic   special    ??      100  20    --
# Reversal      fighting  physical    ??      100  15    --
# Final Gambit  fighting   special    ??      100   5    --
# Fling             dark  physical    ??      100  10    --
# Heat Crash        fire  physical    ??      100  10    --
# Gyro Ball        steel  physical    ??      100   5    --
# Magnitude       ground  physical    ??      100  30    --
# Endeavor        normal  physical    ??      100   5    --
# Heavy Slam       steel  physical    ??      100  10    --
# Trump Card      normal   special    ??       --   5    --
# Bide            normal  physical    ??       --  10    --
# Super Fang      normal  physical    ??       90  10    --
# Flail           normal  physical    ??      100  15    --
# Low Kick      fighting  physical    ??      100  20    --
# Psywave        psychic   special    ??       80  15    --
# Sonicboom       normal   special    ??       90  20    --
# Me First        normal     other    ??       --  20    --
# Fissure         ground  physical    ??       30   5    --
# Horn Drill      normal  physical    ??       30   5    --
# Counter       fighting  physical    ??      100  20    --
# Seismic Toss  fighting  physical    ??      100  20    --
# Beat Up           dark  physical    ??      100  10    --
# Night Shade      ghost   special    ??      100  15    --
# Punishment        dark  physical    ??      100   5    --
# Sheer Cold         ice   special    ??       30   5    --
# Electro Ball  electric   special    ??      100  10    --
# Dragon Rage     dragon   special    ??      100  10    --
# Guillotine      normal  physical    ??       30   5    --
# Metal Burst      steel  physical    ??      100  10    --
# Spit Up         normal   special    ??      100  10    --
#
#                                                            INFO
# MOVE
# Wring Out     The user powerfully wrings the target. The mor...
# Hidden Power  A unique attack that varies in type and intens...
# Frustration   A full-power attack that grows more powerful t...
# Return        A full-power attack that grows more powerful t...
# Grass Knot    The user snares the target with grass and trip...
# Natural Gift  The user draws power to attack by using its he...
# Mirror Coat   A retaliation move that counters any special a...
# Reversal      An all-out attack that becomes more powerful t...
# Final Gambit  The user risks everything to attack its target...
# Fling         The user flings its held item at the target to...
# Heat Crash    The user slams its target with its flame- cove...
# Gyro Ball     The user tackles the target with a high-speed ...
# Magnitude     The user looses a ground-shaking quake affecti...
# Endeavor      An attack move that cuts down the target's HP ...
# Heavy Slam    The user slams into the target with its heavy ...
# Trump Card    The fewer PP this move has, the greater its at...
# Bide          The user endures attacks for two turns, then s...
# Super Fang    The user chomps hard on the target with its sh...
# Flail         The user flails about aimlessly to attack. It ...
# Low Kick      A powerful low kick that makes the target fall...
# Psywave       The target is attacked with an odd  psychic wa...
# Sonicboom     The target is hit with a destructive shock wav...
# Me First      The user tries to cut ahead of the target to s...
# Fissure       The user opens up a fissure in the ground and ...
# Horn Drill    The user stabs the target with a horn that rot...
# Counter       A retaliation move that counters any physical ...
# Seismic Toss  The target is thrown using the power of gravit...
# Beat Up       The user gets all party Pokémon to attack the ...
# Night Shade   The user makes the target see a frightening mi...
# Punishment    This attack's power increases the more the tar...
# Sheer Cold    The target is attacked with a blast of absolut...
# Electro Ball  The user hurls an electric orb at the target. ...
# Dragon Rage   This attack hits the target with a shock wave ...
# Guillotine    A vicious, tearing attack with big pincers. Th...
# Metal Burst   The user retaliates with much greater power ag...
# Spit Up       The power stored using the move Stockpile is r...
