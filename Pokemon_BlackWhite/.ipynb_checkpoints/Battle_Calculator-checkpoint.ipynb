# %% [markdown]
# # Preliminaries

# %%
import pandas as pd  #importing all the important packages
import numpy as np
import matplotlib.pyplot as plt #currently not used
import seaborn as sns #currently not used
import pickle

# %% [markdown]
# Import the table containing pokedex pokemon data for generation 5.

# %%
pickle_in = open('gen5_pokemon.pickle','rb')
pokemon = pickle.load(pickle_in)

# %% [markdown]
# Import the table containing all moves data for each pokemon in generation 5.

# %%
pickle_in = open('all_gen5_moves.pickle','rb')
moves = pickle.load(pickle_in)
# Out:
#                  TYPE  CATEGORY POWER ACCURACY  PP EFF %  LVL  \
# MOVE
# Tackle         normal  physical    50      100  35    --    —
# Leer           normal     other    --      100  30    --    4
# Vine Whip       grass  physical    35      100  15    --    7
# Wrap           normal  physical    15       90  20   100   10
# Growth         normal     other    --       --  40    --   13
# ...               ...       ...   ...      ...  ..   ...  ...
# Magic Coat    psychic     other    --       --  15    --  Egg
# Recycle        normal     other    --       --  10    --  Egg
# Sleep Talk     normal     other    --       --  10    --  Egg
# Snore          normal   special    40      100  15    --  Egg
# Zen Headbutt  psychic  physical    80       90  15    --  Egg
#
#                                                            INFO   POKEMON
# MOVE
# Tackle        A physical attack in which the user charges an...     Snivy
# Leer          The opposing team gains an intimidating leer w...     Snivy
# Vine Whip     The target is struck with slender, whiplike vi...     Snivy
# Wrap          A long body or vines are used to wrap and sque...     Snivy
# Growth        The user's body grows all at once, raising the...     Snivy
# ...                                                         ...       ...
# Magic Coat    A barrier reflects back to the target moves li...  Genesect
# Recycle       The user recycles a held item that has been us...  Genesect
# Sleep Talk    While it is asleep, the user randomly uses one...  Genesect
# Snore         An attack that can be used only if the user is...  Genesect
# Zen Headbutt  The user focuses its willpower to its head and...  Genesect
#
# [8966 rows x 9 columns]

# %% [markdown]
# We can import functions from other .ipynb files using:

# %%
from ipynb.fs.defs.Functions import type_weakness,dmg,base_stats_at_lvl,phys_spec_ratio,get_moves,battle,move_effectiveness,pokemon_effectiveness

# %%
pickle_in = open('../pokemon.pickle','rb')
df = pickle.load(pickle_in)
df.columns = df.columns.str.upper().str.replace('_', '')

# %%
df = df[df['GENERATION'] == 5]
df['TYPE2'] = df['TYPE2'].replace(to_replace=[None], value=np.nan, inplace=True)
#df['TYPE2'].fillna(df['TYPE1'], inplace=True)
df.head(20)
# Out:
#       ID       NAME   HP  ATK  DEF  SPATK  SPDEF  SPD    TYPE1 TYPE2  \
# 494  494    Victini  100  100  100    100    100  100  psychic  None
# 495  495      Snivy   45   45   55     45     55   63    grass  None
# 496  496    Servine   60   60   75     60     75   83    grass  None
# 497  497  Serperior   75   75   95     75     95  113    grass  None
# 498  498      Tepig   65   63   45     45     45   45     fire  None
# 499  499    Pignite   90   93   55     70     55   55     fire  None
# 500  500     Emboar  110  123   65    100     65   65     fire  None
# 501  501   Oshawott   55   55   45     63     45   45    water  None
# 502  502     Dewott   75   75   60     83     60   60    water  None
# 503  503   Samurott   95  100   85    108     70   70    water  None
# 504  504     Patrat   45   55   39     35     39   42   normal  None
# 505  505    Watchog   60   85   69     60     69   77   normal  None
# 506  506   Lillipup   45   60   45     25     45   55   normal  None
# 507  507    Herdier   65   80   65     35     65   60   normal  None
# 508  508  Stoutland   85  110   90     45     90   80   normal  None
# 509  509   Purrloin   41   50   37     50     37   66     dark  None
# 510  510    Liepard   64   88   50     88     50  106     dark  None
# 511  511    Pansage   50   53   48     53     48   64    grass  None
# 512  512   Simisage   75   98   63     98     63  101    grass  None
# 513  513    Pansear   50   53   48     53     48   64     fire  None
#
#          ABILITY1     ABILITY2   ABILITY3  TOTAL  GENERATION  LEGENDARY
# 494  Victory Star         None       None    600           5       True
# 495      Overgrow     Contrary       None    308           5      False
# 496      Overgrow     Contrary       None    413           5      False
# 497      Overgrow     Contrary       None    528           5      False
# 498         Blaze    Thick Fat       None    308           5      False
# 499         Blaze    Thick Fat       None    418           5      False
# 500         Blaze     Reckless       None    528           5      False
# 501       Torrent  Shell Armor       None    308           5      False
# 502       Torrent  Shell Armor       None    413           5      False
# 503       Torrent  Shell Armor       None    528           5      False
# 504      Run Away     Keen Eye   Analytic    255           5      False
# 505    Illuminate     Keen Eye   Analytic    420           5      False
# 506  Vital Spirit       Pickup   Run Away    275           5      False
# 507    Intimidate    Sand Rush    Scrappy    370           5      False
# 508    Intimidate    Sand Rush    Scrappy    500           5      False
# 509        Limber     Unburden  Prankster    281           5      False
# 510        Limber     Unburden  Prankster    446           5      False
# 511      Gluttony     Overgrow       None    316           5      False
# 512      Gluttony     Overgrow       None    498           5      False
# 513      Gluttony        Blaze       None    316           5      False
