# %% [markdown]
# # Preliminaries

# %%
import pandas as pd  #importing all the important packages
import numpy as np
import matplotlib.pyplot as plt #currently not used
import seaborn as sns #currently not used
import pickle

# %% [markdown]
# We reformate the dataframe to make it more useful for analysis including using the pokemon name as the index instead of it's pokedex number.

# %%
#plot style
plt.style.use('fivethirtyeight')
#load file with data
pickle_in = open('pokemon.pickle','rb')
df = pickle.load(pickle_in)
#change into upper case
df.columns = df.columns.str.upper().str.replace('_', '') 
#some values in TYPE2 are so they have to be filled or deleted
df['TYPE2'] = df['TYPE2'].replace(to_replace=[None], value=np.nan, inplace=True) #change None to NaN in Type2
df['TYPE2'].fillna(df['TYPE1'], inplace=True) #fill NaN values in Type2 with corresponding values of Type
#change and set the index to the name attribute
df = df.set_index('NAME')
#drop the columns with axis=1
#axis=0 is for rows
df=df.drop(['ID'],axis=1)

# %%
print('The columns of the dataset are: ',df.columns) #show the dataframe columns
print('The shape of the dataframe is: ',df.shape)    #shape of the dataframe
# Out:
# The columns of the dataset are:  Index(['HP', 'ATK', 'DEF', 'SPATK', 'SPDEF', 'SPD', 'TYPE1', 'TYPE2',
#        'ABILITY1', 'ABILITY2', 'ABILITY3', 'TOTAL', 'GENERATION', 'LEGENDARY'],
#       dtype='object')
# The shape of the dataframe is:  (905, 14)

# %% [markdown]
# The dataframe has 14 columns and 905 rows accounting for the full pokedex up until generation 8. We now print the dataframe (in pokedex order).

# %%
df
# Out:
#               HP  ATK  DEF  SPATK  SPDEF  SPD     TYPE1     TYPE2  \
# NAME
# Bulbasaur     45   49   49     65     65   45     grass     grass
# Ivysaur       60   62   63     80     80   60     grass     grass
# Venusaur      80   82   83    100    100   80     grass     grass
# Charmander    39   52   43     60     50   65      fire      fire
# Charmeleon    58   64   58     80     65   80      fire      fire
# ...          ...  ...  ...    ...    ...  ...       ...       ...
# Ursaluna     130  140  105     45     80   50    ground    ground
# Basculegion  120  112   65     80     75   78     water     water
# Sneasler      80  130   60     40     80  120  fighting  fighting
# Overqwil      85  115   95     65     65   85      dark      dark
# Enamorus      74  115   70    135     80  106     fairy     fairy
#
#                  ABILITY1      ABILITY2      ABILITY3  TOTAL  GENERATION  \
# NAME
# Bulbasaur        Overgrow   Chlorophyll          None    318           1
# Ivysaur          Overgrow   Chlorophyll          None    405           1
# Venusaur         Overgrow   Chlorophyll          None    525           1
# Charmander          Blaze   Solar Power          None    309           1
# Charmeleon          Blaze   Solar Power          None    405           1
# ...                   ...           ...           ...    ...         ...
# Ursaluna             Guts   Bulletproof       Unnerve    550           8
# Basculegion       Rattled  Adaptability  Mold Breaker    530           8
# Sneasler         Pressure  Poison Touch          None    510           8
# Overqwil     Poison Point    Swift Swim    Intimidate    510           8
# Enamorus           Healer      Contrary          None    580           8
#
#              LEGENDARY
# NAME
# Bulbasaur        False
# Ivysaur          False
# Venusaur         False
# Charmander       False
# Charmeleon       False
# ...                ...
# Ursaluna         False
# Basculegion      False
# Sneasler         False
# Overqwil         False
# Enamorus          True
#
# [905 rows x 14 columns]

# %% [markdown]
# # Initial Analysis

# %%
#Initial stats of dataframe (rounded to 0 dp)
df_summary = df.describe().round(0)
df_summary
# Out:
#           HP    ATK    DEF  SPATK  SPDEF    SPD  TOTAL  GENERATION
# count  905.0  905.0  905.0  905.0  905.0  905.0  905.0       905.0
# mean    69.0   77.0   72.0   70.0   70.0   66.0  424.0         4.0
# std     26.0   30.0   29.0   29.0   27.0   28.0  112.0         2.0
# min      1.0    5.0    5.0   10.0   20.0    5.0  175.0         1.0
# 25%     50.0   55.0   50.0   46.0   50.0   45.0  320.0         2.0
# 50%     65.0   75.0   68.0   65.0   65.0   65.0  440.0         4.0
# 75%     80.0   98.0   90.0   90.0   85.0   85.0  500.0         6.0
# max    255.0  181.0  230.0  173.0  230.0  200.0  720.0         8.0

# %% [markdown]
# # Strongest Pokemon by Type

# %% [markdown]
# We consider all the pokemon in the dataset and ordering by 'TOTAL' we consider which is the strongest of each typing. We do this for both primary typing and secondary typing seperately. The way this is done programmatically is we order all the pokemon based on the value of 'TOTAL' and then keep only the first appearance of each typing. E.g. Arceus is the first normal type and any further normal types are dropped from the dataframe.

# %%
type1 = df.drop(['TYPE2'],axis=1) #drop column 'TYPE 2'
type1 = type1.sort_values(by='TOTAL', ascending=False) #descending order by 'TOTAL'
type1 = type1.drop_duplicates(subset=['TYPE1'],keep='first') #since the rows are now sorted in descending order

# %% [markdown]
# To display the table we drop unnecessary columns (e.g. 'ABILITY' and 'GENERATION') and we also highlight values the pokemon has which are in the top or bottom 25% of pokemon stats who are fully evolved, shown in green or red respectively (these numbers were calculated externally).

# %%
type1.drop(['ABILITY1'],axis=1).drop(['ABILITY2'],axis=1).drop(['ABILITY3'],axis=1).style.apply(lambda x: ["background: green" if((i==0 and v >= 95) or (i==1 and v>=110) or (i==2 and v>=90) or (i==3 and v>99) or (i==4 and v>=90) or (i==5 and v>100)) else "" for i, v in enumerate(x)], axis = 1).apply(lambda x: ["background: red" if((i==0 and v <= 70) or (i==1 and v<=75) or (i==2 and v<=65) or (i==3 and v<=60) or (i==4 and v<63) or (i==5 and v<55)) else "" for i, v in enumerate(x)], axis=1)
# Out:
# <style  type="text/css" >
#     #T_1284cfc8_17cf_11ed_8862_acde48001122row0_col0 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row0_col1 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row0_col2 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row0_col3 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row0_col4 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row0_col5 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row1_col0 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row1_col2 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row1_col3 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row1_col4 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row1_col5 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row2_col0 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row2_col1 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row2_col2 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row2_col3 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row2_col4 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row3_col0 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row3_col2 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row3_col3 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row3_col4 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row4_col1 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row4_col2 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row4_col3 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row4_col4 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row5_col0 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row5_col1 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row5_col2 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row5_col3 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row5_col4 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row6_col0 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row6_col1 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row6_col2 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row6_col3 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row6_col4 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row6_col5 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row7_col0 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row7_col1 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row7_col2 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row7_col3 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row7_col4 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row8_col0 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row8_col1 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row8_col2 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row8_col3 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row8_col4 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row9_col0 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row9_col1 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row9_col2 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row9_col3 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row9_col4 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row10_col0 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row10_col1 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row10_col2 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row10_col3 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row10_col4 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row11_col1 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row11_col2 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row11_col4 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row11_col5 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row12_col0 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row12_col2 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row12_col3 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row12_col4 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row13_col1 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row13_col3 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row13_col5 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row14_col0 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row14_col1 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row14_col2 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row14_col4 {
#             background:  green;
#             : ;
#         }    #T_1284cfc8_17cf_11ed_8862_acde48001122row15_col1 {
#             background:  green;
#             : ;
#         }

# %% [markdown]
# Note these are all legendary pokemon, which we would most likely expect. We now do the same for the secondary typing.

# %%
type2 = df.drop(['TYPE1'],axis=1) #drop 'TYPE 1'
type2 = type2.sort_values(by='TOTAL', ascending=False) #descending order by 'TOTAL'
type2 = type2.drop_duplicates(subset=['TYPE2'],keep='first') #since the rows are now sorted in descending order
type2.drop(['ABILITY1'],axis=1).drop(['ABILITY2'],axis=1).drop(['ABILITY3'],axis=1).style.apply(lambda x: ["background: green" if((i==0 and v >= 95) or (i==1 and v>=110) or (i==2 and v>=90) or (i==3 and v>99) or (i==4 and v>=90) or (i==5 and v>100)) else "" for i, v in enumerate(x)], axis = 1).apply(lambda x: ["background: red" if((i==0 and v <= 70) or (i==1 and v<=75) or (i==2 and v<=65) or (i==3 and v<=60) or (i==4 and v<63) or (i==5 and v<55)) else "" for i, v in enumerate(x)], axis=1)
# Out:
# <style  type="text/css" >
#     #T_1295aa78_17cf_11ed_8862_acde48001122row0_col0 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row0_col1 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row0_col2 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row0_col3 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row0_col4 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row0_col5 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row1_col0 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row1_col2 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row1_col3 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row1_col4 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row1_col5 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row2_col0 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row2_col1 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row2_col2 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row2_col3 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row2_col4 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row3_col0 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row3_col2 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row3_col3 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row3_col4 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row4_col1 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row4_col2 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row4_col3 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row4_col4 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row5_col0 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row5_col1 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row5_col2 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row5_col3 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row5_col4 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row6_col0 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row6_col1 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row6_col2 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row6_col3 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row6_col4 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row6_col5 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row7_col0 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row7_col1 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row7_col2 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row7_col3 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row7_col4 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row8_col0 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row8_col1 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row8_col2 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row8_col3 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row8_col4 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row9_col0 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row9_col1 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row9_col2 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row9_col3 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row9_col4 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row10_col0 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row10_col1 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row10_col2 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row10_col3 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row10_col4 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row11_col1 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row11_col2 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row11_col4 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row11_col5 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row12_col0 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row12_col2 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row12_col3 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row12_col4 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row13_col1 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row13_col3 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row13_col5 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row14_col0 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row14_col1 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row14_col2 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row14_col4 {
#             background:  green;
#             : ;
#         }    #T_1295aa78_17cf_11ed_8862_acde48001122row15_col1 {
#             background:  green;
#             : ;
#         }

# %% [markdown]
# # STRONGEST POKEMON BY INDIVDUAL STATS

# %% [markdown]
# We now sort the pokemon by individual base stats, we can see which pokemon have the highest scores in HP, speed (SPD), attack (ATK), defence (DEF), special attack (SPATK) and special defence (SPDEF). Note again we use the red and green markings to highlight top and bottom quartile rankings of the pokemon's stat. We also drop all the columns we do not need for these rankings ('TYPE', 'ABILITY', 'GENERATION', etc)

# %%
#DROP EXTRA COLUMNS (INCLUDING TYPES)
stats=df.drop(['TYPE1'],axis=1).drop(['TYPE2'],axis=1).drop(['ABILITY1'],axis=1).drop(['ABILITY2'],axis=1).drop(['ABILITY3'],axis=1) #drop the columns with axis=1;axis=0 is for rows

# %%
# sort pokemon by speed and print the top 10 fastest (.head(10))
spd = stats.sort_values(by='SPD', ascending=False).drop(['GENERATION'],axis=1)
spd.head(10).style.apply(lambda x: ["background: green" if((i==0 and v >= 95) or (i==1 and v>=110) or (i==2 and v>=90) or (i==3 and v>99) or (i==4 and v>=90) or (i==5 and v>100)) else "" for i, v in enumerate(x)], axis = 1).apply(lambda x: ["background: red" if((i==0 and v <= 70) or (i==1 and v<=75) or (i==2 and v<=65) or (i==3 and v<=60) or (i==4 and v<63) or (i==5 and v<55)) else "" for i, v in enumerate(x)], axis=1)
# Out:
# <style  type="text/css" >
#     #T_129ffeb0_17cf_11ed_8862_acde48001122row0_col2 {
#             : ;
#             background:  red;
#         }    #T_129ffeb0_17cf_11ed_8862_acde48001122row0_col3 {
#             background:  green;
#             : ;
#         }    #T_129ffeb0_17cf_11ed_8862_acde48001122row0_col4 {
#             : ;
#             background:  red;
#         }    #T_129ffeb0_17cf_11ed_8862_acde48001122row0_col5 {
#             background:  green;
#             : ;
#         }    #T_129ffeb0_17cf_11ed_8862_acde48001122row1_col0 {
#             : ;
#             background:  red;
#         }    #T_129ffeb0_17cf_11ed_8862_acde48001122row1_col2 {
#             : ;
#             background:  red;
#         }    #T_129ffeb0_17cf_11ed_8862_acde48001122row1_col3 {
#             : ;
#             background:  red;
#         }    #T_129ffeb0_17cf_11ed_8862_acde48001122row1_col4 {
#             : ;
#             background:  red;
#         }    #T_129ffeb0_17cf_11ed_8862_acde48001122row1_col5 {
#             background:  green;
#             : ;
#         }    #T_129ffeb0_17cf_11ed_8862_acde48001122row2_col1 {
#             background:  green;
#             : ;
#         }    #T_129ffeb0_17cf_11ed_8862_acde48001122row2_col2 {
#             : ;
#             background:  red;
#         }    #T_129ffeb0_17cf_11ed_8862_acde48001122row2_col3 {
#             background:  green;
#             : ;
#         }    #T_129ffeb0_17cf_11ed_8862_acde48001122row2_col4 {
#             : ;
#             background:  red;
#         }    #T_129ffeb0_17cf_11ed_8862_acde48001122row2_col5 {
#             background:  green;
#             : ;
#         }    #T_129ffeb0_17cf_11ed_8862_acde48001122row3_col0 {
#             : ;
#             background:  red;
#         }    #T_129ffeb0_17cf_11ed_8862_acde48001122row3_col1 {
#             : ;
#             background:  red;
#         }    #T_129ffeb0_17cf_11ed_8862_acde48001122row3_col5 {
#             background:  green;
#             : ;
#         }    #T_129ffeb0_17cf_11ed_8862_acde48001122row4_col0 {
#             : ;
#             background:  red;
#         }    #T_129ffeb0_17cf_11ed_8862_acde48001122row4_col1 {
#             background:  green;
#             : ;
#         }    #T_129ffeb0_17cf_11ed_8862_acde48001122row4_col2 {
#             : ;
#             background:  red;
#         }    #T_129ffeb0_17cf_11ed_8862_acde48001122row4_col3 {
#             background:  green;
#             : ;
#         }    #T_129ffeb0_17cf_11ed_8862_acde48001122row4_col4 {
#             : ;
#             background:  red;
#         }    #T_129ffeb0_17cf_11ed_8862_acde48001122row4_col5 {
#             background:  green;
#             : ;
#         }    #T_129ffeb0_17cf_11ed_8862_acde48001122row5_col1 {
#             : ;
#             background:  red;
#         }    #T_129ffeb0_17cf_11ed_8862_acde48001122row5_col2 {
#             : ;
#             background:  red;
#         }    #T_129ffeb0_17cf_11ed_8862_acde48001122row5_col3 {
#             background:  green;
#             : ;
#         }    #T_129ffeb0_17cf_11ed_8862_acde48001122row5_col4 {
#             : ;
#             background:  red;
#         }    #T_129ffeb0_17cf_11ed_8862_acde48001122row5_col5 {
#             background:  green;
#             : ;
#         }    #T_129ffeb0_17cf_11ed_8862_acde48001122row6_col1 {
#             background:  green;
#             : ;
#         }    #T_129ffeb0_17cf_11ed_8862_acde48001122row6_col3 {
#             background:  green;
#             : ;
#         }    #T_129ffeb0_17cf_11ed_8862_acde48001122row6_col5 {
#             background:  green;
#             : ;
#         }    #T_129ffeb0_17cf_11ed_8862_acde48001122row7_col1 {
#             background:  green;
#             : ;
#         }    #T_129ffeb0_17cf_11ed_8862_acde48001122row7_col3 {
#             background:  green;
#             : ;
#         }    #T_129ffeb0_17cf_11ed_8862_acde48001122row7_col5 {
#             background:  green;
#             : ;
#         }    #T_129ffeb0_17cf_11ed_8862_acde48001122row8_col1 {
#             background:  green;
#             : ;
#         }    #T_129ffeb0_17cf_11ed_8862_acde48001122row8_col2 {
#             background:  green;
#             : ;
#         }    #T_129ffeb0_17cf_11ed_8862_acde48001122row8_col4 {
#             background:  green;
#             : ;
#         }    #T_129ffeb0_17cf_11ed_8862_acde48001122row8_col5 {
#             background:  green;
#             : ;
#         }    #T_129ffeb0_17cf_11ed_8862_acde48001122row9_col1 {
#             background:  green;
#             : ;
#         }    #T_129ffeb0_17cf_11ed_8862_acde48001122row9_col2 {
#             background:  green;
#             : ;
#         }    #T_129ffeb0_17cf_11ed_8862_acde48001122row9_col4 {
#             background:  green;
#             : ;
#         }    #T_129ffeb0_17cf_11ed_8862_acde48001122row9_col5 {
#             background:  green;
#             : ;
#         }</style><table id="T_129ffeb0_17cf_11ed_8862_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >HP</th>        <th class="col_heading level0 col1" >ATK</th>        <th class="col_heading level0 col2" >DEF</th>        <th class="col_heading level0 col3" >SPATK</th>        <th class="col_heading level0 col4" >SPDEF</th>        <th class="col_heading level0 col5" >SPD</th>        <th class="col_heading level0 col6" >TOTAL</th>        <th class="col_heading level0 col7" >LEGENDARY</th>    </tr>    <tr>        <th class="index_name level0" >NAME</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_129ffeb0_17cf_11ed_8862_acde48001122level0_row0" class="row_heading level0 row0" >Regieleki</th>
#                         <td id="T_129ffeb0_17cf_11ed_8862_acde48001122row0_col0" class="data row0 col0" >80</td>
#                         <td id="T_129ffeb0_17cf_11ed_8862_acde48001122row0_col1" class="data row0 col1" >100</td>
#                         <td id="T_129ffeb0_17cf_11ed_8862_acde48001122row0_col2" class="data row0 col2" >50</td>
#                         <td id="T_129ffeb0_17cf_11ed_8862_acde48001122row0_col3" class="data row0 col3" >100</td>
#                         <td id="T_129ffeb0_17cf_11ed_8862_acde48001122row0_col4" class="data row0 col4" >50</td>
#                         <td id="T_129ffeb0_17cf_11ed_8862_acde48001122row0_col5" class="data row0 col5" >200</td>
#                         <td id="T_129ffeb0_17cf_11ed_8862_acde48001122row0_col6" class="data row0 col6" >580</td>
#                         <td id="T_129ffeb0_17cf_11ed_8862_acde48001122row0_col7" class="data row0 col7" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_129ffeb0_17cf_11ed_8862_acde48001122level0_row1" class="row_heading level0 row1" >Ninjask</th>
#                         <td id="T_129ffeb0_17cf_11ed_8862_acde48001122row1_col0" class="data row1 col0" >61</td>
#                         <td id="T_129ffeb0_17cf_11ed_8862_acde48001122row1_col1" class="data row1 col1" >90</td>
#                         <td id="T_129ffeb0_17cf_11ed_8862_acde48001122row1_col2" class="data row1 col2" >45</td>
#                         <td id="T_129ffeb0_17cf_11ed_8862_acde48001122row1_col3" class="data row1 col3" >50</td>
#                         <td id="T_129ffeb0_17cf_11ed_8862_acde48001122row1_col4" class="data row1 col4" >50</td>
#                         <td id="T_129ffeb0_17cf_11ed_8862_acde48001122row1_col5" class="data row1 col5" >160</td>
#                         <td id="T_129ffeb0_17cf_11ed_8862_acde48001122row1_col6" class="data row1 col6" >456</td>
#                         <td id="T_129ffeb0_17cf_11ed_8862_acde48001122row1_col7" class="data row1 col7" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_129ffeb0_17cf_11ed_8862_acde48001122level0_row2" class="row_heading level0 row2" >Pheromosa</th>
#                         <td id="T_129ffeb0_17cf_11ed_8862_acde48001122row2_col0" class="data row2 col0" >7

# %%
# sort pokemon by HP and print the top 10 highest (.head(10))
hp = stats.sort_values(by='HP', ascending=False).drop(['GENERATION'],axis=1)
hp.head(10).style.apply(lambda x: ["background: green" if((i==0 and v >= 95) or (i==1 and v>=110) or (i==2 and v>=90) or (i==3 and v>99) or (i==4 and v>=90) or (i==5 and v>100)) else "" for i, v in enumerate(x)], axis = 1).apply(lambda x: ["background: red" if((i==0 and v <= 70) or (i==1 and v<=75) or (i==2 and v<=65) or (i==3 and v<=60) or (i==4 and v<63) or (i==5 and v<55)) else "" for i, v in enumerate(x)], axis=1)
# Out:
# <style  type="text/css" >
#     #T_12a87112_17cf_11ed_8862_acde48001122row0_col0 {
#             background:  green;
#             : ;
#         }    #T_12a87112_17cf_11ed_8862_acde48001122row0_col1 {
#             : ;
#             background:  red;
#         }    #T_12a87112_17cf_11ed_8862_acde48001122row0_col2 {
#             : ;
#             background:  red;
#         }    #T_12a87112_17cf_11ed_8862_acde48001122row0_col4 {
#             background:  green;
#             : ;
#         }    #T_12a87112_17cf_11ed_8862_acde48001122row1_col0 {
#             background:  green;
#             : ;
#         }    #T_12a87112_17cf_11ed_8862_acde48001122row1_col1 {
#             : ;
#             background:  red;
#         }    #T_12a87112_17cf_11ed_8862_acde48001122row1_col2 {
#             : ;
#             background:  red;
#         }    #T_12a87112_17cf_11ed_8862_acde48001122row1_col3 {
#             : ;
#             background:  red;
#         }    #T_12a87112_17cf_11ed_8862_acde48001122row1_col4 {
#             background:  green;
#             : ;
#         }    #T_12a87112_17cf_11ed_8862_acde48001122row1_col5 {
#             : ;
#             background:  red;
#         }    #T_12a87112_17cf_11ed_8862_acde48001122row2_col0 {
#             background:  green;
#             : ;
#         }    #T_12a87112_17cf_11ed_8862_acde48001122row2_col2 {
#             : ;
#             background:  red;
#         }    #T_12a87112_17cf_11ed_8862_acde48001122row2_col4 {
#             : ;
#             background:  red;
#         }    #T_12a87112_17cf_11ed_8862_acde48001122row2_col5 {
#             : ;
#             background:  red;
#         }    #T_12a87112_17cf_11ed_8862_acde48001122row3_col0 {
#             background:  green;
#             : ;
#         }    #T_12a87112_17cf_11ed_8862_acde48001122row3_col2 {
#             : ;
#             background:  red;
#         }    #T_12a87112_17cf_11ed_8862_acde48001122row3_col3 {
#             background:  green;
#             : ;
#         }    #T_12a87112_17cf_11ed_8862_acde48001122row3_col4 {
#             : ;
#             background:  red;
#         }    #T_12a87112_17cf_11ed_8862_acde48001122row4_col0 {
#             background:  green;
#             : ;
#         }    #T_12a87112_17cf_11ed_8862_acde48001122row4_col1 {
#             : ;
#             background:  red;
#         }    #T_12a87112_17cf_11ed_8862_acde48001122row4_col2 {
#             : ;
#             background:  red;
#         }    #T_12a87112_17cf_11ed_8862_acde48001122row4_col3 {
#             : ;
#             background:  red;
#         }    #T_12a87112_17cf_11ed_8862_acde48001122row4_col4 {
#             : ;
#             background:  red;
#         }    #T_12a87112_17cf_11ed_8862_acde48001122row4_col5 {
#             : ;
#             background:  red;
#         }    #T_12a87112_17cf_11ed_8862_acde48001122row5_col0 {
#             background:  green;
#             : ;
#         }    #T_12a87112_17cf_11ed_8862_acde48001122row5_col2 {
#             : ;
#             background:  red;
#         }    #T_12a87112_17cf_11ed_8862_acde48001122row5_col4 {
#             : ;
#             background:  red;
#         }    #T_12a87112_17cf_11ed_8862_acde48001122row6_col0 {
#             background:  green;
#             : ;
#         }    #T_12a87112_17cf_11ed_8862_acde48001122row6_col1 {
#             : ;
#             background:  red;
#         }    #T_12a87112_17cf_11ed_8862_acde48001122row6_col3 {
#             : ;
#             background:  red;
#         }    #T_12a87112_17cf_11ed_8862_acde48001122row6_col4 {
#             : ;
#             background:  red;
#         }    #T_12a87112_17cf_11ed_8862_acde48001122row7_col0 {
#             background:  green;
#             : ;
#         }    #T_12a87112_17cf_11ed_8862_acde48001122row7_col1 {
#             background:  green;
#             : ;
#         }    #T_12a87112_17cf_11ed_8862_acde48001122row7_col2 {
#             : ;
#             background:  red;
#         }    #T_12a87112_17cf_11ed_8862_acde48001122row7_col4 {
#             background:  green;
#             : ;
#         }    #T_12a87112_17cf_11ed_8862_acde48001122row7_col5 {
#             : ;
#             background:  red;
#         }    #T_12a87112_17cf_11ed_8862_acde48001122row8_col0 {
#             background:  green;
#             : ;
#         }    #T_12a87112_17cf_11ed_8862_acde48001122row8_col2 {
#             background:  green;
#             : ;
#         }    #T_12a87112_17cf_11ed_8862_acde48001122row8_col3 {
#             background:  green;
#             : ;
#         }    #T_12a87112_17cf_11ed_8862_acde48001122row8_col4 {
#             background:  green;
#             : ;
#         }    #T_12a87112_17cf_11ed_8862_acde48001122row9_col0 {
#             background:  green;
#             : ;
#         }    #T_12a87112_17cf_11ed_8862_acde48001122row9_col1 {
#             background:  green;
#             : ;
#         }    #T_12a87112_17cf_11ed_8862_acde48001122row9_col2 {
#             background:  green;
#             : ;
#         }</style><table id="T_12a87112_17cf_11ed_8862_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >HP</th>        <th class="col_heading level0 col1" >ATK</th>        <th class="col_heading level0 col2" >DEF</th>        <th class="col_heading level0 col3" >SPATK</th>        <th class="col_heading level0 col4" >SPDEF</th>        <th class="col_heading level0 col5" >SPD</th>        <th class="col_heading level0 col6" >TOTAL</th>        <th class="col_heading level0 col7" >LEGENDARY</th>    </tr>    <tr>        <th class="index_name level0" >NAME</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_12a87112_17cf_11ed_8862_acde48001122level0_row0" class="row_heading level0 row0" >Blissey</th>
#                         <td id="T_12a87112_17cf_11ed_8862_acde48001122row0_col0" class="data row0 col0" >255</td>
#                         <td id="T_12a87112_17cf_11ed_8862_acde48001122row0_col1" class="data row0 col1" >10</td>
#                         <td id="T_12a87112_17cf_11ed_8862_acde48001122row0_col2" class="data row0 col2" >10</td>
#                         <td id="T_12a87112_17cf_11ed_8862_acde48001122row0_col3" class="data row0 col3" >75</td>
#                         <td id="T_12a87112_17cf_11ed_8862_acde48001122row0_col4" class="data row0 col4" >135</td>
#                         <td id="T_12a87112_17cf_11ed_8862_acde48001122row0_col5" class="data row0 col5" >55</td>
#                         <td id="T_12a87112_17cf_11ed_8862_acde48001122row0_col6" class="data row0 col6" >540</td>
#                         <td id="T_12a87112_17cf_11ed_8862_acde48001122row0_col7" class="data row0 col7" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_12a87112_17cf_11ed_8862_acde48001122level0_row1" class="row_heading level0 row1" >Chansey</th>
#                         <td id="T_12a87112_17cf_11ed_8862_acde48001122row1_col0" class="data row1 col0" >250</td>
#                         <td id="T_12a87112_17cf_11ed_8862_acde48001122row1_col1" class="data row1 col1" >5</td>
#                         <td id="T_12a87112_17cf_11ed_8862_acde48001122row1_col2" class="data row1 col2" >5</td>
#                         <td id="T_12a87112_17cf_11ed_8862_acde48001122row1_col3" class="data row1 col3" >35</td>
#                         <td id="T_12a87112_17cf_11ed_8862_acde48001122row1_col4" class="data row1 col4" >105</td>
#                         <td id="T_12a87112_17cf_11ed_8862_acde48001122row1_col5" class="data row1 col5" >50</td>
#                         <td id="T_12a87112_17cf_11ed_8862_acde48001122row1_col6" class="data row1 col6" >450</td>
#                         <td id="T_12a87112_17cf_11ed_8862_acde48001122row1_col7" class="data row1 col7" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_12a87112_17cf_11ed_8862_acde48001122level0_row2" class="row_heading level0 row2" >Guzzlord</th>

# %%
# sort pokemon by attack and print the top 10 fastest (.head(10))
atk = stats.sort_values(by='ATK', ascending=False).drop(['GENERATION'],axis=1)
atk.head(10).style.apply(lambda x: ["background: green" if((i==0 and v >= 95) or (i==1 and v>=110) or (i==2 and v>=90) or (i==3 and v>99) or (i==4 and v>=90) or (i==5 and v>100)) else "" for i, v in enumerate(x)], axis = 1).apply(lambda x: ["background: red" if((i==0 and v <= 70) or (i==1 and v<=75) or (i==2 and v<=65) or (i==3 and v<=60) or (i==4 and v<63) or (i==5 and v<55)) else "" for i, v in enumerate(x)], axis=1)
# Out:
# <style  type="text/css" >
#     #T_12b11d12_17cf_11ed_8862_acde48001122row0_col0 {
#             : ;
#             background:  red;
#         }    #T_12b11d12_17cf_11ed_8862_acde48001122row0_col1 {
#             background:  green;
#             : ;
#         }    #T_12b11d12_17cf_11ed_8862_acde48001122row0_col2 {
#             background:  green;
#             : ;
#         }    #T_12b11d12_17cf_11ed_8862_acde48001122row0_col3 {
#             : ;
#             background:  red;
#         }    #T_12b11d12_17cf_11ed_8862_acde48001122row0_col4 {
#             : ;
#             background:  red;
#         }    #T_12b11d12_17cf_11ed_8862_acde48001122row0_col5 {
#             background:  green;
#             : ;
#         }    #T_12b11d12_17cf_11ed_8862_acde48001122row1_col0 {
#             background:  green;
#             : ;
#         }    #T_12b11d12_17cf_11ed_8862_acde48001122row1_col1 {
#             background:  green;
#             : ;
#         }    #T_12b11d12_17cf_11ed_8862_acde48001122row1_col2 {
#             : ;
#             background:  red;
#         }    #T_12b11d12_17cf_11ed_8862_acde48001122row1_col4 {
#             : ;
#             background:  red;
#         }    #T_12b11d12_17cf_11ed_8862_acde48001122row2_col0 {
#             background:  green;
#             : ;
#         }    #T_12b11d12_17cf_11ed_8862_acde48001122row2_col1 {
#             background:  green;
#             : ;
#         }    #T_12b11d12_17cf_11ed_8862_acde48001122row2_col2 {
#             background:  green;
#             : ;
#         }    #T_12b11d12_17cf_11ed_8862_acde48001122row3_col0 {
#             background:  green;
#             : ;
#         }    #T_12b11d12_17cf_11ed_8862_acde48001122row3_col1 {
#             background:  green;
#             : ;
#         }    #T_12b11d12_17cf_11ed_8862_acde48001122row3_col2 {
#             background:  green;
#             : ;
#         }    #T_12b11d12_17cf_11ed_8862_acde48001122row3_col4 {
#             background:  green;
#             : ;
#         }    #T_12b11d12_17cf_11ed_8862_acde48001122row4_col0 {
#             : ;
#             background:  red;
#         }    #T_12b11d12_17cf_11ed_8862_acde48001122row4_col1 {
#             background:  green;
#             : ;
#         }    #T_12b11d12_17cf_11ed_8862_acde48001122row4_col2 {
#             : ;
#             background:  red;
#         }    #T_12b11d12_17cf_11ed_8862_acde48001122row4_col3 {
#             background:  green;
#             : ;
#         }    #T_12b11d12_17cf_11ed_8862_acde48001122row4_col4 {
#             : ;
#             background:  red;
#         }    #T_12b11d12_17cf_11ed_8862_acde48001122row4_col5 {
#             background:  green;
#             : ;
#         }    #T_12b11d12_17cf_11ed_8862_acde48001122row5_col0 {
#             background:  green;
#             : ;
#         }    #T_12b11d12_17cf_11ed_8862_acde48001122row5_col1 {
#             background:  green;
#             : ;
#         }    #T_12b11d12_17cf_11ed_8862_acde48001122row5_col2 {
#             background:  green;
#             : ;
#         }    #T_12b11d12_17cf_11ed_8862_acde48001122row5_col3 {
#             background:  green;
#             : ;
#         }    #T_12b11d12_17cf_11ed_8862_acde48001122row5_col4 {
#             background:  green;
#             : ;
#         }    #T_12b11d12_17cf_11ed_8862_acde48001122row6_col0 {
#             background:  green;
#             : ;
#         }    #T_12b11d12_17cf_11ed_8862_acde48001122row6_col1 {
#             background:  green;
#             : ;
#         }    #T_12b11d12_17cf_11ed_8862_acde48001122row6_col2 {
#             background:  green;
#             : ;
#         }    #T_12b11d12_17cf_11ed_8862_acde48001122row6_col3 {
#             background:  green;
#             : ;
#         }    #T_12b11d12_17cf_11ed_8862_acde48001122row6_col4 {
#             background:  green;
#             : ;
#         }    #T_12b11d12_17cf_11ed_8862_acde48001122row7_col0 {
#             background:  green;
#             : ;
#         }    #T_12b11d12_17cf_11ed_8862_acde48001122row7_col1 {
#             background:  green;
#             : ;
#         }    #T_12b11d12_17cf_11ed_8862_acde48001122row7_col2 {
#             background:  green;
#             : ;
#         }    #T_12b11d12_17cf_11ed_8862_acde48001122row7_col3 {
#             background:  green;
#             : ;
#         }    #T_12b11d12_17cf_11ed_8862_acde48001122row7_col4 {
#             background:  green;
#             : ;
#         }    #T_12b11d12_17cf_11ed_8862_acde48001122row8_col1 {
#             background:  green;
#             : ;
#         }    #T_12b11d12_17cf_11ed_8862_acde48001122row8_col2 {
#             background:  green;
#             : ;
#         }    #T_12b11d12_17cf_11ed_8862_acde48001122row8_col3 {
#             : ;
#             background:  red;
#         }    #T_12b11d12_17cf_11ed_8862_acde48001122row9_col0 {
#             background:  green;
#             : ;
#         }    #T_12b11d12_17cf_11ed_8862_acde48001122row9_col1 {
#             background:  green;
#             : ;
#         }    #T_12b11d12_17cf_11ed_8862_acde48001122row9_col2 {
#             background:  green;
#             : ;
#         }    #T_12b11d12_17cf_11ed_8862_acde48001122row9_col4 {
#             background:  green;
#             : ;
#         }    #T_12b11d12_17cf_11ed_8862_acde48001122row9_col5 {
#             : ;
#             background:  red;
#         }</style><table id="T_12b11d12_17cf_11ed_8862_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >HP</th>        <th class="col_heading level0 col1" >ATK</th>        <th class="col_heading level0 col2" >DEF</th>        <th class="col_heading level0 col3" >SPATK</th>        <th class="col_heading level0 col4" >SPDEF</th>        <th class="col_heading level0 col5" >SPD</th>        <th class="col_heading level0 col6" >TOTAL</th>        <th class="col_heading level0 col7" >LEGENDARY</th>    </tr>    <tr>        <th class="index_name level0" >NAME</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_12b11d12_17cf_11ed_8862_acde48001122level0_row0" class="row_heading level0 row0" >Kartana</th>
#                         <td id="T_12b11d12_17cf_11ed_8862_acde48001122row0_col0" class="data row0 col0" >59</td>
#                         <td id="T_12b11d12_17cf_11ed_8862_acde48001122row0_col1" class="data row0 col1" >181</td>
#                         <td id="T_12b11d12_17cf_11ed_8862_acde48001122row0_col2" class="data row0 col2" >131</td>
#                         <td id="T_12b11d12_17cf_11ed_8862_acde48001122row0_col3" class="data row0 col3" >59</td>
#                         <td id="T_12b11d12_17cf_11ed_8862_acde48001122row0_col4" class="data row0 col4" >31</td>
#                         <td id="T_12b11d12_17cf_11ed_8862_acde48001122row0_col5" class="data row0 col5" >109</td>
#                         <td id="T_12b11d12_17cf_11ed_8862_acde48001122row0_col6" class="data row0 col6" >570</td>
#                         <td id="T_12b11d12_17cf_11ed_8862_acde48001122row0_col7" class="data row0 col7" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_12b11d12_17cf_11ed_8862_acde48001122level0_row1" class="row_heading level0 row1" >Rampardos</th>
#                         <td id="T_12b11d12_17cf_11ed_8862_acde48001122row1_col0" class="data row1 col0" >97</td>
#                         <td id="T_12b11d12_17cf_11ed_8862_acde48001122row1_col1" class="data row1 col1" >165</td>
#                         <td id="T_12b11d12_17cf_11ed_8862_acde48001122row1_col2" class="data row1 col2" >60</td>
#                         <td id="T_12b11d12_17cf_11ed_8862_acde48001122row1_col3" class="data row1 col3" >65</td>
#                         <td id="T_12b11d12_17cf_11ed_8862_acde48001122row1_col4" class="data row1 col4" >50</td>
#                         <td id="T_12b11d12_17cf_11ed_8862_acde48001122row1_col5" class="data row1 col5" >58</td>
#                         <td id="T_12b11d12

# %%
# sort pokemon by special attack and print the top 10 fastest (.head(10))
spatk = stats.sort_values(by='SPATK', ascending=False).drop(['GENERATION'],axis=1)
spatk.head(10).style.apply(lambda x: ["background: green" if((i==0 and v >= 95) or (i==1 and v>=110) or (i==2 and v>=90) or (i==3 and v>99) or (i==4 and v>=90) or (i==5 and v>100)) else "" for i, v in enumerate(x)], axis = 1).apply(lambda x: ["background: red" if((i==0 and v <= 70) or (i==1 and v<=75) or (i==2 and v<=65) or (i==3 and v<=60) or (i==4 and v<63) or (i==5 and v<55)) else "" for i, v in enumerate(x)], axis=1)
# Out:
# <style  type="text/css" >
#     #T_12b981b4_17cf_11ed_8862_acde48001122row0_col3 {
#             background:  green;
#             : ;
#         }    #T_12b981b4_17cf_11ed_8862_acde48001122row1_col0 {
#             background:  green;
#             : ;
#         }    #T_12b981b4_17cf_11ed_8862_acde48001122row1_col1 {
#             background:  green;
#             : ;
#         }    #T_12b981b4_17cf_11ed_8862_acde48001122row1_col2 {
#             background:  green;
#             : ;
#         }    #T_12b981b4_17cf_11ed_8862_acde48001122row1_col3 {
#             background:  green;
#             : ;
#         }    #T_12b981b4_17cf_11ed_8862_acde48001122row1_col4 {
#             background:  green;
#             : ;
#         }    #T_12b981b4_17cf_11ed_8862_acde48001122row1_col5 {
#             background:  green;
#             : ;
#         }    #T_12b981b4_17cf_11ed_8862_acde48001122row2_col0 {
#             : ;
#             background:  red;
#         }    #T_12b981b4_17cf_11ed_8862_acde48001122row2_col1 {
#             background:  green;
#             : ;
#         }    #T_12b981b4_17cf_11ed_8862_acde48001122row2_col2 {
#             : ;
#             background:  red;
#         }    #T_12b981b4_17cf_11ed_8862_acde48001122row2_col3 {
#             background:  green;
#             : ;
#         }    #T_12b981b4_17cf_11ed_8862_acde48001122row2_col5 {
#             background:  green;
#             : ;
#         }    #T_12b981b4_17cf_11ed_8862_acde48001122row3_col1 {
#             background:  green;
#             : ;
#         }    #T_12b981b4_17cf_11ed_8862_acde48001122row3_col2 {
#             background:  green;
#             : ;
#         }    #T_12b981b4_17cf_11ed_8862_acde48001122row3_col3 {
#             background:  green;
#             : ;
#         }    #T_12b981b4_17cf_11ed_8862_acde48001122row3_col4 {
#             background:  green;
#             : ;
#         }    #T_12b981b4_17cf_11ed_8862_acde48001122row4_col0 {
#             : ;
#             background:  red;
#         }    #T_12b981b4_17cf_11ed_8862_acde48001122row4_col1 {
#             background:  green;
#             : ;
#         }    #T_12b981b4_17cf_11ed_8862_acde48001122row4_col2 {
#             : ;
#             background:  red;
#         }    #T_12b981b4_17cf_11ed_8862_acde48001122row4_col3 {
#             background:  green;
#             : ;
#         }    #T_12b981b4_17cf_11ed_8862_acde48001122row4_col4 {
#             : ;
#             background:  red;
#         }    #T_12b981b4_17cf_11ed_8862_acde48001122row4_col5 {
#             background:  green;
#             : ;
#         }    #T_12b981b4_17cf_11ed_8862_acde48001122row5_col0 {
#             background:  green;
#             : ;
#         }    #T_12b981b4_17cf_11ed_8862_acde48001122row5_col1 {
#             background:  green;
#             : ;
#         }    #T_12b981b4_17cf_11ed_8862_acde48001122row5_col2 {
#             background:  green;
#             : ;
#         }    #T_12b981b4_17cf_11ed_8862_acde48001122row5_col3 {
#             background:  green;
#             : ;
#         }    #T_12b981b4_17cf_11ed_8862_acde48001122row5_col4 {
#             background:  green;
#             : ;
#         }    #T_12b981b4_17cf_11ed_8862_acde48001122row6_col0 {
#             background:  green;
#             : ;
#         }    #T_12b981b4_17cf_11ed_8862_acde48001122row6_col2 {
#             background:  green;
#             : ;
#         }    #T_12b981b4_17cf_11ed_8862_acde48001122row6_col3 {
#             background:  green;
#             : ;
#         }    #T_12b981b4_17cf_11ed_8862_acde48001122row6_col4 {
#             background:  green;
#             : ;
#         }    #T_12b981b4_17cf_11ed_8862_acde48001122row7_col0 {
#             background:  green;
#             : ;
#         }    #T_12b981b4_17cf_11ed_8862_acde48001122row7_col1 {
#             background:  green;
#             : ;
#         }    #T_12b981b4_17cf_11ed_8862_acde48001122row7_col2 {
#             background:  green;
#             : ;
#         }    #T_12b981b4_17cf_11ed_8862_acde48001122row7_col3 {
#             background:  green;
#             : ;
#         }    #T_12b981b4_17cf_11ed_8862_acde48001122row7_col4 {
#             background:  green;
#             : ;
#         }    #T_12b981b4_17cf_11ed_8862_acde48001122row8_col1 {
#             background:  green;
#             : ;
#         }    #T_12b981b4_17cf_11ed_8862_acde48001122row8_col2 {
#             : ;
#             background:  red;
#         }    #T_12b981b4_17cf_11ed_8862_acde48001122row8_col3 {
#             background:  green;
#             : ;
#         }    #T_12b981b4_17cf_11ed_8862_acde48001122row8_col4 {
#             background:  green;
#             : ;
#         }    #T_12b981b4_17cf_11ed_8862_acde48001122row9_col0 {
#             background:  green;
#             : ;
#         }    #T_12b981b4_17cf_11ed_8862_acde48001122row9_col1 {
#             background:  green;
#             : ;
#         }    #T_12b981b4_17cf_11ed_8862_acde48001122row9_col2 {
#             background:  green;
#             : ;
#         }    #T_12b981b4_17cf_11ed_8862_acde48001122row9_col3 {
#             background:  green;
#             : ;
#         }    #T_12b981b4_17cf_11ed_8862_acde48001122row9_col4 {
#             background:  green;
#             : ;
#         }</style><table id="T_12b981b4_17cf_11ed_8862_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >HP</th>        <th class="col_heading level0 col1" >ATK</th>        <th class="col_heading level0 col2" >DEF</th>        <th class="col_heading level0 col3" >SPATK</th>        <th class="col_heading level0 col4" >SPDEF</th>        <th class="col_heading level0 col5" >SPD</th>        <th class="col_heading level0 col6" >TOTAL</th>        <th class="col_heading level0 col7" >LEGENDARY</th>    </tr>    <tr>        <th class="index_name level0" >NAME</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_12b981b4_17cf_11ed_8862_acde48001122level0_row0" class="row_heading level0 row0" >Xurkitree</th>
#                         <td id="T_12b981b4_17cf_11ed_8862_acde48001122row0_col0" class="data row0 col0" >83</td>
#                         <td id="T_12b981b4_17cf_11ed_8862_acde48001122row0_col1" class="data row0 col1" >89</td>
#                         <td id="T_12b981b4_17cf_11ed_8862_acde48001122row0_col2" class="data row0 col2" >71</td>
#                         <td id="T_12b981b4_17cf_11ed_8862_acde48001122row0_col3" class="data row0 col3" >173</td>
#                         <td id="T_12b981b4_17cf_11ed_8862_acde48001122row0_col4" class="data row0 col4" >71</td>
#                         <td id="T_12b981b4_17cf_11ed_8862_acde48001122row0_col5" class="data row0 col5" >83</td>
#                         <td id="T_12b981b4_17cf_11ed_8862_acde48001122row0_col6" class="data row0 col6" >570</td>
#                         <td id="T_12b981b4_17cf_11ed_8862_acde48001122row0_col7" class="data row0 col7" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_12b981b4_17cf_11ed_8862_acde48001122level0_row1" class="row_heading level0 row1" >Mewtwo</th>
#                         <td id="T_12b981b4_17cf_11ed_8862_acde48001122row1_col0" class="data row1 col0" >106</td>
#                         <td id="T_12b981b4_17cf_11ed_8862_acde48001122row1_col1" class="data row1 col1" >110</td>
#                         <td id="T_12b981b4_17cf_11ed_8862_acde48001122row1_col2" class="data row1 col2" >90</td>
#                         <td id="T_12b981b4_17cf_11ed_8862_acde48001122row1_col3" class="data row1 col3" >154</td>
#                         <td id="T_12b981b4_17cf_11ed_8862_acde48001122row1_col4" class="data row1 col4" >90</td>
#                         <td id="T_12b981b4_17cf_11ed_8862_acde48001122row1_col5" class="data row1 col5" >130</td>
#                         <td id="T_12b981b4_17cf_11ed_8862_acde48001122row1_col6" class="data row1 col6" >680</td>
#                         <td id="

# %%
# sort pokemon by special defence and print the top 10 fastest (.head(10))
spdef = stats.sort_values(by='SPDEF', ascending=False).drop(['GENERATION'],axis=1)
spdef.head(10).style.apply(lambda x: ["background: green" if((i==0 and v >= 95) or (i==1 and v>=110) or (i==2 and v>=90) or (i==3 and v>99) or (i==4 and v>=90) or (i==5 and v>100)) else "" for i, v in enumerate(x)], axis = 1).apply(lambda x: ["background: red" if((i==0 and v <= 70) or (i==1 and v<=75) or (i==2 and v<=65) or (i==3 and v<=60) or (i==4 and v<63) or (i==5 and v<55)) else "" for i, v in enumerate(x)], axis=1)
# Out:
# <style  type="text/css" >
#     #T_12c23322_17cf_11ed_8862_acde48001122row0_col0 {
#             : ;
#             background:  red;
#         }    #T_12c23322_17cf_11ed_8862_acde48001122row0_col1 {
#             : ;
#             background:  red;
#         }    #T_12c23322_17cf_11ed_8862_acde48001122row0_col2 {
#             background:  green;
#             : ;
#         }    #T_12c23322_17cf_11ed_8862_acde48001122row0_col3 {
#             : ;
#             background:  red;
#         }    #T_12c23322_17cf_11ed_8862_acde48001122row0_col4 {
#             background:  green;
#             : ;
#         }    #T_12c23322_17cf_11ed_8862_acde48001122row0_col5 {
#             : ;
#             background:  red;
#         }    #T_12c23322_17cf_11ed_8862_acde48001122row1_col1 {
#             : ;
#             background:  red;
#         }    #T_12c23322_17cf_11ed_8862_acde48001122row1_col2 {
#             background:  green;
#             : ;
#         }    #T_12c23322_17cf_11ed_8862_acde48001122row1_col3 {
#             background:  green;
#             : ;
#         }    #T_12c23322_17cf_11ed_8862_acde48001122row1_col4 {
#             background:  green;
#             : ;
#         }    #T_12c23322_17cf_11ed_8862_acde48001122row1_col5 {
#             : ;
#             background:  red;
#         }    #T_12c23322_17cf_11ed_8862_acde48001122row2_col0 {
#             background:  green;
#             : ;
#         }    #T_12c23322_17cf_11ed_8862_acde48001122row2_col1 {
#             background:  green;
#             : ;
#         }    #T_12c23322_17cf_11ed_8862_acde48001122row2_col2 {
#             background:  green;
#             : ;
#         }    #T_12c23322_17cf_11ed_8862_acde48001122row2_col3 {
#             background:  green;
#             : ;
#         }    #T_12c23322_17cf_11ed_8862_acde48001122row2_col4 {
#             background:  green;
#             : ;
#         }    #T_12c23322_17cf_11ed_8862_acde48001122row3_col0 {
#             background:  green;
#             : ;
#         }    #T_12c23322_17cf_11ed_8862_acde48001122row3_col2 {
#             background:  green;
#             : ;
#         }    #T_12c23322_17cf_11ed_8862_acde48001122row3_col4 {
#             background:  green;
#             : ;
#         }    #T_12c23322_17cf_11ed_8862_acde48001122row3_col5 {
#             background:  green;
#             : ;
#         }    #T_12c23322_17cf_11ed_8862_acde48001122row4_col1 {
#             : ;
#             background:  red;
#         }    #T_12c23322_17cf_11ed_8862_acde48001122row4_col3 {
#             background:  green;
#             : ;
#         }    #T_12c23322_17cf_11ed_8862_acde48001122row4_col4 {
#             background:  green;
#             : ;
#         }    #T_12c23322_17cf_11ed_8862_acde48001122row5_col0 {
#             : ;
#             background:  red;
#         }    #T_12c23322_17cf_11ed_8862_acde48001122row5_col2 {
#             background:  green;
#             : ;
#         }    #T_12c23322_17cf_11ed_8862_acde48001122row5_col3 {
#             background:  green;
#             : ;
#         }    #T_12c23322_17cf_11ed_8862_acde48001122row5_col4 {
#             background:  green;
#             : ;
#         }    #T_12c23322_17cf_11ed_8862_acde48001122row5_col5 {
#             : ;
#             background:  red;
#         }    #T_12c23322_17cf_11ed_8862_acde48001122row6_col3 {
#             background:  green;
#             : ;
#         }    #T_12c23322_17cf_11ed_8862_acde48001122row6_col4 {
#             background:  green;
#             : ;
#         }    #T_12c23322_17cf_11ed_8862_acde48001122row7_col0 {
#             : ;
#             background:  red;
#         }    #T_12c23322_17cf_11ed_8862_acde48001122row7_col1 {
#             : ;
#             background:  red;
#         }    #T_12c23322_17cf_11ed_8862_acde48001122row7_col2 {
#             background:  green;
#             : ;
#         }    #T_12c23322_17cf_11ed_8862_acde48001122row7_col3 {
#             : ;
#             background:  red;
#         }    #T_12c23322_17cf_11ed_8862_acde48001122row7_col4 {
#             background:  green;
#             : ;
#         }    #T_12c23322_17cf_11ed_8862_acde48001122row7_col5 {
#             : ;
#             background:  red;
#         }    #T_12c23322_17cf_11ed_8862_acde48001122row8_col0 {
#             : ;
#             background:  red;
#         }    #T_12c23322_17cf_11ed_8862_acde48001122row8_col1 {
#             : ;
#             background:  red;
#         }    #T_12c23322_17cf_11ed_8862_acde48001122row8_col2 {
#             background:  green;
#             : ;
#         }    #T_12c23322_17cf_11ed_8862_acde48001122row8_col4 {
#             background:  green;
#             : ;
#         }    #T_12c23322_17cf_11ed_8862_acde48001122row8_col5 {
#             : ;
#             background:  red;
#         }    #T_12c23322_17cf_11ed_8862_acde48001122row9_col1 {
#             : ;
#             background:  red;
#         }    #T_12c23322_17cf_11ed_8862_acde48001122row9_col2 {
#             background:  green;
#             : ;
#         }    #T_12c23322_17cf_11ed_8862_acde48001122row9_col4 {
#             background:  green;
#             : ;
#         }    #T_12c23322_17cf_11ed_8862_acde48001122row9_col5 {
#             : ;
#             background:  red;
#         }</style><table id="T_12c23322_17cf_11ed_8862_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >HP</th>        <th class="col_heading level0 col1" >ATK</th>        <th class="col_heading level0 col2" >DEF</th>        <th class="col_heading level0 col3" >SPATK</th>        <th class="col_heading level0 col4" >SPDEF</th>        <th class="col_heading level0 col5" >SPD</th>        <th class="col_heading level0 col6" >TOTAL</th>        <th class="col_heading level0 col7" >LEGENDARY</th>    </tr>    <tr>        <th class="index_name level0" >NAME</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_12c23322_17cf_11ed_8862_acde48001122level0_row0" class="row_heading level0 row0" >Shuckle</th>
#                         <td id="T_12c23322_17cf_11ed_8862_acde48001122row0_col0" class="data row0 col0" >20</td>
#                         <td id="T_12c23322_17cf_11ed_8862_acde48001122row0_col1" class="data row0 col1" >10</td>
#                         <td id="T_12c23322_17cf_11ed_8862_acde48001122row0_col2" class="data row0 col2" >230</td>
#                         <td id="T_12c23322_17cf_11ed_8862_acde48001122row0_col3" class="data row0 col3" >10</td>
#                         <td id="T_12c23322_17cf_11ed_8862_acde48001122row0_col4" class="data row0 col4" >230</td>
#                         <td id="T_12c23322_17cf_11ed_8862_acde48001122row0_col5" class="data row0 col5" >5</td>
#                         <td id="T_12c23322_17cf_11ed_8862_acde48001122row0_col6" class="data row0 col6" >505</td>
#                         <td id="T_12c23322_17cf_11ed_8862_acde48001122row0_col7" class="data row0 col7" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_12c23322_17cf_11ed_8862_acde48001122level0_row1" class="row_heading level0 row1" >Regice</th>
#                         <td id="T_12c23322_17cf_11ed_8862_acde48001122row1_col0" class="data row1 col0" >80</td>
#                         <td id="T_12c23322_17cf_11ed_8862_acde48001122row1_col1" class="data row1 col1" >50</td>
#                         <td id="T_12c23322_17cf_11ed_8862_acde48001122row1_col2" class="data row1 col2" >100</td>
#                         <td id="T_12c23322_17cf_11ed_8862_acde48001122row1_col3" class="data row1 col3" >100</td>
#                         <td id="T_12c23322_17cf_11ed_8862_acde48001122row1_col4" class="data row1 col4" >200</td>
#                         <td id="T_12c23322_17cf_11ed_8862_acde48001122row1_col5" class="data row1 col5" >50</td>
#                         <td id="T_12c23322_17cf_11ed_8862_acde48001122row1_col6" class="data row1 col6" >580</td>
#                         <td id="T_12c23322_17cf_11ed_8862_

# %%
# sort pokemon by defence and print the top 10 fastest (.head(10))
defence = stats.sort_values(by='DEF', ascending=False).drop(['GENERATION'],axis=1)
defence.head(10).style.apply(lambda x: ["background: green" if((i==0 and v >= 95) or (i==1 and v>=110) or (i==2 and v>=90) or (i==3 and v>99) or (i==4 and v>=90) or (i==5 and v>100)) else "" for i, v in enumerate(x)], axis = 1).apply(lambda x: ["background: red" if((i==0 and v <= 70) or (i==1 and v<=75) or (i==2 and v<=65) or (i==3 and v<=60) or (i==4 and v<63) or (i==5 and v<55)) else "" for i, v in enumerate(x)], axis=1)
# Out:
# <style  type="text/css" >
#     #T_12caa6d8_17cf_11ed_8862_acde48001122row0_col0 {
#             : ;
#             background:  red;
#         }    #T_12caa6d8_17cf_11ed_8862_acde48001122row0_col1 {
#             : ;
#             background:  red;
#         }    #T_12caa6d8_17cf_11ed_8862_acde48001122row0_col2 {
#             background:  green;
#             : ;
#         }    #T_12caa6d8_17cf_11ed_8862_acde48001122row0_col3 {
#             : ;
#             background:  red;
#         }    #T_12caa6d8_17cf_11ed_8862_acde48001122row0_col4 {
#             background:  green;
#             : ;
#         }    #T_12caa6d8_17cf_11ed_8862_acde48001122row0_col5 {
#             : ;
#             background:  red;
#         }    #T_12caa6d8_17cf_11ed_8862_acde48001122row1_col0 {
#             : ;
#             background:  red;
#         }    #T_12caa6d8_17cf_11ed_8862_acde48001122row1_col1 {
#             background:  green;
#             : ;
#         }    #T_12caa6d8_17cf_11ed_8862_acde48001122row1_col2 {
#             background:  green;
#             : ;
#         }    #T_12caa6d8_17cf_11ed_8862_acde48001122row1_col3 {
#             : ;
#             background:  red;
#         }    #T_12caa6d8_17cf_11ed_8862_acde48001122row1_col4 {
#             background:  green;
#             : ;
#         }    #T_12caa6d8_17cf_11ed_8862_acde48001122row1_col5 {
#             : ;
#             background:  red;
#         }    #T_12caa6d8_17cf_11ed_8862_acde48001122row2_col2 {
#             background:  green;
#             : ;
#         }    #T_12caa6d8_17cf_11ed_8862_acde48001122row2_col3 {
#             : ;
#             background:  red;
#         }    #T_12caa6d8_17cf_11ed_8862_acde48001122row2_col4 {
#             background:  green;
#             : ;
#         }    #T_12caa6d8_17cf_11ed_8862_acde48001122row2_col5 {
#             : ;
#             background:  red;
#         }    #T_12caa6d8_17cf_11ed_8862_acde48001122row3_col2 {
#             background:  green;
#             : ;
#         }    #T_12caa6d8_17cf_11ed_8862_acde48001122row3_col3 {
#             : ;
#             background:  red;
#         }    #T_12caa6d8_17cf_11ed_8862_acde48001122row3_col5 {
#             : ;
#             background:  red;
#         }    #T_12caa6d8_17cf_11ed_8862_acde48001122row4_col0 {
#             background:  green;
#             : ;
#         }    #T_12caa6d8_17cf_11ed_8862_acde48001122row4_col1 {
#             background:  green;
#             : ;
#         }    #T_12caa6d8_17cf_11ed_8862_acde48001122row4_col2 {
#             background:  green;
#             : ;
#         }    #T_12caa6d8_17cf_11ed_8862_acde48001122row4_col3 {
#             : ;
#             background:  red;
#         }    #T_12caa6d8_17cf_11ed_8862_acde48001122row4_col4 {
#             : ;
#             background:  red;
#         }    #T_12caa6d8_17cf_11ed_8862_acde48001122row4_col5 {
#             : ;
#             background:  red;
#         }    #T_12caa6d8_17cf_11ed_8862_acde48001122row5_col0 {
#             : ;
#             background:  red;
#         }    #T_12caa6d8_17cf_11ed_8862_acde48001122row5_col1 {
#             background:  green;
#             : ;
#         }    #T_12caa6d8_17cf_11ed_8862_acde48001122row5_col2 {
#             background:  green;
#             : ;
#         }    #T_12caa6d8_17cf_11ed_8862_acde48001122row5_col3 {
#             : ;
#             background:  red;
#         }    #T_12caa6d8_17cf_11ed_8862_acde48001122row5_col4 {
#             : ;
#             background:  red;
#         }    #T_12caa6d8_17cf_11ed_8862_acde48001122row5_col5 {
#             : ;
#             background:  red;
#         }    #T_12caa6d8_17cf_11ed_8862_acde48001122row6_col0 {
#             : ;
#             background:  red;
#         }    #T_12caa6d8_17cf_11ed_8862_acde48001122row6_col2 {
#             background:  green;
#             : ;
#         }    #T_12caa6d8_17cf_11ed_8862_acde48001122row6_col4 {
#             : ;
#             background:  red;
#         }    #T_12caa6d8_17cf_11ed_8862_acde48001122row7_col0 {
#             : ;
#             background:  red;
#         }    #T_12caa6d8_17cf_11ed_8862_acde48001122row7_col1 {
#             : ;
#             background:  red;
#         }    #T_12caa6d8_17cf_11ed_8862_acde48001122row7_col2 {
#             background:  green;
#             : ;
#         }    #T_12caa6d8_17cf_11ed_8862_acde48001122row7_col3 {
#             : ;
#             background:  red;
#         }    #T_12caa6d8_17cf_11ed_8862_acde48001122row7_col4 {
#             background:  green;
#             : ;
#         }    #T_12caa6d8_17cf_11ed_8862_acde48001122row7_col5 {
#             : ;
#             background:  red;
#         }    #T_12caa6d8_17cf_11ed_8862_acde48001122row8_col0 {
#             : ;
#             background:  red;
#         }    #T_12caa6d8_17cf_11ed_8862_acde48001122row8_col1 {
#             : ;
#             background:  red;
#         }    #T_12caa6d8_17cf_11ed_8862_acde48001122row8_col2 {
#             background:  green;
#             : ;
#         }    #T_12caa6d8_17cf_11ed_8862_acde48001122row8_col3 {
#             : ;
#             background:  red;
#         }    #T_12caa6d8_17cf_11ed_8862_acde48001122row8_col4 {
#             : ;
#             background:  red;
#         }    #T_12caa6d8_17cf_11ed_8862_acde48001122row9_col0 {
#             : ;
#             background:  red;
#         }    #T_12caa6d8_17cf_11ed_8862_acde48001122row9_col1 {
#             : ;
#             background:  red;
#         }    #T_12caa6d8_17cf_11ed_8862_acde48001122row9_col2 {
#             background:  green;
#             : ;
#         }    #T_12caa6d8_17cf_11ed_8862_acde48001122row9_col3 {
#             : ;
#             background:  red;
#         }    #T_12caa6d8_17cf_11ed_8862_acde48001122row9_col4 {
#             background:  green;
#             : ;
#         }    #T_12caa6d8_17cf_11ed_8862_acde48001122row9_col5 {
#             : ;
#             background:  red;
#         }</style><table id="T_12caa6d8_17cf_11ed_8862_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >HP</th>        <th class="col_heading level0 col1" >ATK</th>        <th class="col_heading level0 col2" >DEF</th>        <th class="col_heading level0 col3" >SPATK</th>        <th class="col_heading level0 col4" >SPDEF</th>        <th class="col_heading level0 col5" >SPD</th>        <th class="col_heading level0 col6" >TOTAL</th>        <th class="col_heading level0 col7" >LEGENDARY</th>    </tr>    <tr>        <th class="index_name level0" >NAME</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_12caa6d8_17cf_11ed_8862_acde48001122level0_row0" class="row_heading level0 row0" >Shuckle</th>
#                         <td id="T_12caa6d8_17cf_11ed_8862_acde48001122row0_col0" class="data row0 col0" >20</td>
#                         <td id="T_12caa6d8_17cf_11ed_8862_acde48001122row0_col1" class="data row0 col1" >10</td>
#                         <td id="T_12caa6d8_17cf_11ed_8862_acde48001122row0_col2" class="data row0 col2" >230</td>
#                         <td id="T_12caa6d8_17cf_11ed_8862_acde48001122row0_col3" class="data row0 col3" >10</td>
#                         <td id="T_12caa6d8_17cf_11ed_8862_acde48001122row0_col4" class="data row0 col4" >230</td>
#                         <td id="T_12caa6d8_17cf_11ed_8862_acde48001122row0_col5" class="data row0 col5" >5</td>
#                         <td id="T_12caa6d8_17cf_11ed_8862_acde48001122row0_col6" class="data row0 col6" >505</td>
#                         <td id="T_12caa6d8_17cf_11ed_8862_acde48001122row0_col7" class="data row0 col7" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_12caa6d8_17cf_11ed_8862_acde48001122level0_row1" class="row_heading level0 row1" >Stakataka</th>
#                         <td id="T_12caa6d8_17cf_11ed_8862_acde48001122row1_col0" class="data row1 col0" >61</td>
#                         <td id="T_12caa6d8_17cf_11ed_8862_acde48001122row1_col1" class="data

# %% [markdown]
# # Pokemon with 'TOTAL' over 500 and 525

# %%
print(sum(stats['TOTAL'] >= 500), sum(stats['TOTAL'] >= 525)) #number of pokemon with base totals >=500 and >=525
# Out:
# 254 165

# %% [markdown]
# There are an incredible 254 pokemon with totals greater than 500 and 165 greater than 525. If we look at that in each generation we can see the similar numbers of pokemon in each generation have stats of 500 or more. When we consider the number of pokemon in each generation we realise that in generation 1 about 20% of pokemon have stats >= 500, generation 2 is about 25%, generation 6 is about 31%, and generation 8 is about 40%. Using this trend we can see a known concept of 'power creep', as new pokemon need to be stronger to keep the game interesting and influence the game on arrival rather than be unnecessary compared to original pokemon.

# %%
gen1 = stats[stats['GENERATION'] == 1]
print("Generation 1:",sum(gen1['TOTAL'] >= 500), sum(gen1['TOTAL'] >= 525), gen1['TOTAL'].count(), '%:',(sum(gen1['TOTAL'] >= 500)/gen1['TOTAL'].count()*100).round(1))
gen2 = stats[stats['GENERATION'] == 2]
print("Generation 2:",sum(gen2['TOTAL'] >= 500), sum(gen2['TOTAL'] >= 525), gen2['TOTAL'].count(), '%:',(sum(gen2['TOTAL'] >= 500)/gen2['TOTAL'].count()*100).round(1))
gen3 = stats[stats['GENERATION'] == 3]
print("Generation 3:",sum(gen3['TOTAL'] >= 500), sum(gen3['TOTAL'] >= 525), gen3['TOTAL'].count(), '%:',(sum(gen3['TOTAL'] >= 500)/gen3['TOTAL'].count()*100).round(1))
gen4 = stats[stats['GENERATION'] == 4]
print("Generation 4:",sum(gen4['TOTAL'] >= 500), sum(gen4['TOTAL'] >= 525), gen4['TOTAL'].count(), '%:',(sum(gen4['TOTAL'] >= 500)/gen4['TOTAL'].count()*100).round(1))
gen5 = stats[stats['GENERATION'] == 5]
print("Generation 5:",sum(gen5['TOTAL'] >= 500), sum(gen5['TOTAL'] >= 525), gen5['TOTAL'].count(), '%:',(sum(gen5['TOTAL'] >= 500)/gen5['TOTAL'].count()*100).round(1))
gen6 = stats[stats['GENERATION'] == 6]
print("Generation 6:",sum(gen6['TOTAL'] >= 500), sum(gen6['TOTAL'] >= 525), gen6['TOTAL'].count(), '%:',(sum(gen6['TOTAL'] >= 500)/gen6['TOTAL'].count()*100).round(1))
gen7 = stats[stats['GENERATION'] == 7]
print("Generation 7:",sum(gen7['TOTAL'] >= 500), sum(gen7['TOTAL'] >= 525), gen7['TOTAL'].count(), '%:',(sum(gen7['TOTAL'] >= 500)/gen7['TOTAL'].count()*100).round(1))
gen8 = stats[stats['GENERATION'] == 8]
print("Generation 8:",sum(gen8['TOTAL'] >= 500), sum(gen8['TOTAL'] >= 525), gen8['TOTAL'].count(), '%:',(sum(gen8['TOTAL'] >= 500)/gen8['TOTAL'].count()*100).round(1))
# Out:
# Generation 1: 33 18 151 %: 21.9
# Generation 2: 25 15 100 %: 25.0
# Generation 3: 23 19 135 %: 17.0
# Generation 4: 41 31 107 %: 38.3
# Generation 5: 37 21 156 %: 23.7
# Generation 6: 23 14 72 %: 31.9
# Generation 7: 33 28 88 %: 37.5
# Generation 8: 39 19 96 %: 40.6

# %%
#all pokemon with total of 500 plus
stats[stats['TOTAL'] >= 500].sort_values(by='TOTAL', ascending=False).style.apply(lambda x: ["background: green" if((i==0 and v >= 95) or (i==1 and v>=110) or (i==2 and v>=90) or (i==3 and v>99) or (i==4 and v>=90) or (i==5 and v>100)) else "" for i, v in enumerate(x)], axis = 1).apply(lambda x: ["background: red" if((i==0 and v <= 70) or (i==1 and v<=75) or (i==2 and v<=65) or (i==3 and v<=60) or (i==4 and v<63) or (i==5 and v<55)) else "" for i, v in enumerate(x)], axis=1)
# Out:
# <style  type="text/css" >
#     #T_52daff48_17cf_11ed_8862_acde48001122row0_col0 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row0_col1 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row0_col2 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row0_col3 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row0_col4 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row0_col5 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row1_col0 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row1_col2 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row1_col3 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row1_col4 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row1_col5 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row2_col0 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row2_col1 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row2_col2 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row2_col3 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row2_col4 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row3_col0 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row3_col1 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row3_col2 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row3_col3 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row3_col4 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row4_col0 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row4_col1 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row4_col2 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row4_col3 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row4_col4 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row5_col0 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row5_col1 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row5_col2 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row5_col3 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row5_col4 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row5_col5 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row6_col1 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row6_col2 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row6_col3 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row6_col4 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row7_col0 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row7_col2 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row7_col3 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row7_col4 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row8_col0 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row8_col1 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row8_col2 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row8_col3 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row8_col4 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row9_col0 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row9_col2 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row9_col4 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row9_col5 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row10_col0 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row10_col1 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row10_col2 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row10_col3 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row10_col4 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row11_col0 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row11_col1 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row11_col2 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row11_col3 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row11_col4 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row12_col0 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row12_col1 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row12_col2 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row12_col3 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row13_col0 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row13_col1 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row13_col2 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row13_col3 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row13_col4 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row14_col0 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row14_col1 {
#             background:  green;
#             : ;
#         }    #T_52daff48_17cf_11ed_8862_acde48001122row14_col3 {
#             background:  green;
#             : ;
#         }

# %% [markdown]
# Above is the list of all pokemon with 'TOTAL' >= 500. Again we use red and green to mark the strongest and weakest pokemon of each individual stat. It's quite obvious that the pokemon that dominate the table are the pokemon with the 'LEGENDARY' status equal to true. As these pokemon are rare to get in the game it is not always so helpful to include them. Below we consider the same table with legendaries removed.

# %%
#all pokemon with total of 500 plus which are not legendarys
noL = stats[stats['LEGENDARY']==False]
noL[noL['TOTAL'] >= 500].sort_values(by='TOTAL', ascending=False).style.apply(lambda x: ["background: green" if((i==0 and v >= 95) or (i==1 and v>=110) or (i==2 and v>=90) or (i==3 and v>99) or (i==4 and v>=90) or (i==5 and v>100)) else "" for i, v in enumerate(x)], axis = 1).apply(lambda x: ["background: red" if((i==0 and v <= 70) or (i==1 and v<=75) or (i==2 and v<=65) or (i==3 and v<=60) or (i==4 and v<63) or (i==5 and v<55)) else "" for i, v in enumerate(x)], axis=1)
# Out:
# <style  type="text/css" >
#     #T_38d2703a_17d0_11ed_8862_acde48001122row0_col0 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row0_col1 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row0_col2 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row1_col1 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row1_col2 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row1_col4 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row2_col1 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row2_col2 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row2_col3 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row2_col4 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row3_col3 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row3_col4 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row4_col0 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row4_col1 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row4_col2 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row4_col4 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row5_col1 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row5_col2 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row5_col3 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row5_col4 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row6_col0 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row6_col1 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row6_col3 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row7_col2 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row7_col3 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row7_col4 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row8_col1 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row8_col3 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row8_col5 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row9_col0 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row9_col1 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row9_col2 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row9_col5 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row10_col1 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row10_col2 {
#             : ;
#             background:  red;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row10_col3 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row10_col5 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row11_col1 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row11_col3 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row12_col1 {
#             : ;
#             background:  red;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row12_col3 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row12_col4 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row13_col1 {
#             : ;
#             background:  red;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row13_col2 {
#             : ;
#             background:  red;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row13_col3 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row13_col4 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row14_col0 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row14_col1 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row14_col2 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row14_col3 {
#             : ;
#             background:  red;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row14_col5 {
#             : ;
#             background:  red;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row15_col1 {
#             : ;
#             background:  red;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row15_col2 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row15_col3 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row15_col4 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row16_col0 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row16_col1 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row16_col3 {
#             : ;
#             background:  red;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row16_col4 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row17_col1 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row17_col2 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row17_col3 {
#             : ;
#             background:  red;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row18_col0 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row18_col1 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row18_col2 {
#             : ;
#             background:  red;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row18_col4 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row18_col5 {
#             : ;
#             background:  red;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row19_col2 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row19_col4 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row20_col1 {
#             background:  green;
#             : ;
#         }    #T_38d2703a_17d0_11ed_8862_acde48001122row21_col3 {
#             background:  green;
#             : ;
#         }    #T
