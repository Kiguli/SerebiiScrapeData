# %% [markdown]
# # Preliminaries

# %%
import pandas as pd   #importing all the important packages
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
plt.style.use('fivethirtyeight')
pickle_in = open('uptogen8pokemon.pickle','rb')
df = pickle.load(pickle_in)

# %%
#df =  pd.read_csv('Pokemon.csv')  #read the csv file and save it into a variable
df.columns = df.columns.str.upper().str.replace('_', '') #change into upper case
#some values in TYPE2 are empty and thus they have to be filled or deleted
df['TYPE2'] = df['TYPE2'].replace(to_replace=[None], value=np.nan, inplace=True) #change None to NaN in Type2
df['TYPE2'].fillna(df['TYPE1'], inplace=True) #fill NaN values in Type2 with corresponding values of Type
df = df.set_index('NAME') #change and set the index to the name attribute
## The index of Mega Pokemons contained extra and unneeded text. Removed all the text before "Mega"  
df.index = df.index.str.replace(".*(?=Mega)", "")
df=df.drop(['ID'],axis=1) #drop the columns with axis=1;axis=0 is for rows

# %%
df = df.sort_values(by='TOTAL', ascending=False) #order by biggest total at top
#identify partial string to look for
discard = ["Mega "]
#drop rows that contain the partial string "Wes" in the conference column
df = df[~df.index.str.contains('|'.join(discard))] #remove MEGAs
df=df.drop(['GENERATION'],axis=1) #drop the columns with axis=1;axis=0 is for rows
#gen5_noL=gen5_noL.drop(['LEGENDARY'],axis=1) #drop the columns with axis=1;axis=0 is for rows
print('The columns of the dataset are: ',df.columns) #show the dataframe columns
print('The shape of the dataframe is: ',df.shape)    #shape of the dataframe
# Out:
# The columns of the dataset are:  Index(['HP', 'ATK', 'DEF', 'SPATK', 'SPDEF', 'SPD', 'TYPE1', 'TYPE2',
#        'ABILITY1', 'ABILITY2', 'ABILITY3', 'TOTAL'],
#       dtype='object')
# The shape of the dataframe is:  (905, 12)

# %% [markdown]
# # Analysis

# %%
#Avg stat of this generation's pokemon (all pokemon)
df.mean().round(0)
# Out:
# HP        69.0
# ATK       77.0
# DEF       72.0
# SPATK     70.0
# SPDEF     70.0
# SPD       66.0
# TOTAL    424.0
# dtype: float64

# %%
#Avg stat of this generation's pokemon (all pokemon)
#gen5[gen5['FINAL EVO']==True].mean().round(0)

# %%
df_summary = df.describe()
df_summary
# Out:
#                HP         ATK         DEF       SPATK       SPDEF         SPD  \
# count  905.000000  905.000000  905.000000  905.000000  905.000000  905.000000
# mean    69.228729   76.893923   71.951381   69.711602   69.916022   66.090608
# std     26.277444   29.833903   29.465817   29.404633   26.915215   28.455923
# min      1.000000    5.000000    5.000000   10.000000   20.000000    5.000000
# 25%     50.000000   55.000000   50.000000   46.000000   50.000000   45.000000
# 50%     65.000000   75.000000   68.000000   65.000000   65.000000   65.000000
# 75%     80.000000   98.000000   90.000000   90.000000   85.000000   85.000000
# max    255.000000  181.000000  230.000000  173.000000  230.000000  200.000000
#
#             TOTAL
# count  905.000000
# mean   423.792265
# std    111.806965
# min    175.000000
# 25%    320.000000
# 50%    440.000000
# 75%    500.000000
# max    720.000000

# %%
df
# Out:
#              HP  ATK  DEF  SPATK  SPDEF  SPD   TYPE1   TYPE2     ABILITY1  \
# NAME
# Arceus      120  120  120    120    120  120  normal  normal    Multitype
# Eternatus   140   85   95    145     95  130  poison  poison     Pressure
# Xerneas     126  131   95    131     98   99   fairy   fairy   Fairy Aura
# Giratina    150  100  120    100    120   90   ghost   ghost     Pressure
# Palkia       90  120  100    150    120  100   water   water     Pressure
# ...         ...  ...  ...    ...    ...  ...     ...     ...          ...
# Azurill      50   20   40     20     40   20  normal  normal    Thick Fat
# Snom         30   25   35     45     30   20     ice     ice  Shield Dust
# Blipbug      25   20   20     25     45   45     bug     bug        Swarm
# Sunkern      30   30   30     30     30   30   grass   grass  Chlorophyll
# Wishiwashi   45   20   20     25     25   40   water   water    Schooling
#
#                 ABILITY2    ABILITY3  TOTAL
# NAME
# Arceus              None        None    720
# Eternatus           None        None    690
# Xerneas             None        None    680
# Giratina       Telepathy        None    680
# Palkia         Telepathy        None    680
# ...                  ...         ...    ...
# Azurill       Huge Power  Sap Sipper    190
# Snom          Ice Scales        None    185
# Blipbug     Compoundeyes   Telepathy    180
# Sunkern      Solar Power  Early Bird    180
# Wishiwashi          None        None    175
#
# [905 rows x 12 columns]

# %%
#best of each type (using TOTAL and primary typing)
type1 = df.drop(['TYPE2'],axis=1) #drop the columns with axis=1;axis=0 is for rows
type1 = type1.drop_duplicates(subset=['TYPE1'],keep='first') #since the rows are now sorted in descending order
type1.drop(['ABILITY1'],axis=1).drop(['ABILITY2'],axis=1).drop(['ABILITY3'],axis=1).style.apply(lambda x: ["background: green" if((i==0 and v >= 95) or (i==1 and v>=110) or (i==2 and v>=90) or (i==3 and v>99) or (i==4 and v>=90) or (i==5 and v>100)) else "" for i, v in enumerate(x)], axis = 1).apply(lambda x: ["background: red" if((i==0 and v <= 70) or (i==1 and v<=75) or (i==2 and v<=65) or (i==3 and v<=60) or (i==4 and v<63) or (i==5 and v<55)) else "" for i, v in enumerate(x)], axis=1)
# Out:
# <style  type="text/css" >
#     #T_8b077b1e_14df_11ed_877b_acde48001122row0_col0 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row0_col1 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row0_col2 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row0_col3 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row0_col4 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row0_col5 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row1_col0 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row1_col2 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row1_col3 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row1_col4 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row1_col5 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row2_col0 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row2_col1 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row2_col2 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row2_col3 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row2_col4 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row3_col0 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row3_col2 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row3_col3 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row3_col4 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row4_col1 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row4_col2 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row4_col3 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row4_col4 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row5_col0 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row5_col1 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row5_col2 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row5_col3 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row5_col4 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row6_col0 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row6_col1 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row6_col2 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row6_col3 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row6_col4 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row6_col5 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row7_col0 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row7_col1 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row7_col2 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row7_col3 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row7_col4 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row8_col0 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row8_col1 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row8_col2 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row8_col3 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row8_col4 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row9_col0 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row9_col1 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row9_col2 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row9_col3 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row9_col4 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row10_col0 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row10_col1 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row10_col2 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row10_col3 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row10_col4 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row11_col1 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row11_col2 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row11_col4 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row11_col5 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row12_col0 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row12_col2 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row12_col3 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row12_col4 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row13_col1 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row13_col3 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row13_col5 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row14_col0 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row14_col1 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row14_col2 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row14_col4 {
#             background:  green;
#             : ;
#         }    #T_8b077b1e_14df_11ed_877b_acde48001122row15_col1 {
#             background:  green;
#             : ;
#         }

# %%
#best of each type (using TOTAL and primary typing)
type2 = df.drop(['TYPE1'],axis=1) #drop the columns with axis=1;axis=0 is for rows
type2 = type2.drop_duplicates(subset=['TYPE2'],keep='first') #since the rows are now sorted in descending order
type2.drop(['ABILITY1'],axis=1).drop(['ABILITY2'],axis=1).drop(['ABILITY3'],axis=1).style.apply(lambda x: ["background: green" if((i==0 and v >= 95) or (i==1 and v>=110) or (i==2 and v>=90) or (i==3 and v>99) or (i==4 and v>=90) or (i==5 and v>100)) else "" for i, v in enumerate(x)], axis = 1).apply(lambda x: ["background: red" if((i==0 and v <= 70) or (i==1 and v<=75) or (i==2 and v<=65) or (i==3 and v<=60) or (i==4 and v<63) or (i==5 and v<55)) else "" for i, v in enumerate(x)], axis=1)
# Out:
# <style  type="text/css" >
#     #T_8b165ff8_14df_11ed_877b_acde48001122row0_col0 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row0_col1 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row0_col2 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row0_col3 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row0_col4 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row0_col5 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row1_col0 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row1_col2 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row1_col3 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row1_col4 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row1_col5 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row2_col0 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row2_col1 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row2_col2 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row2_col3 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row2_col4 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row3_col0 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row3_col2 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row3_col3 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row3_col4 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row4_col1 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row4_col2 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row4_col3 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row4_col4 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row5_col0 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row5_col1 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row5_col2 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row5_col3 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row5_col4 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row6_col0 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row6_col1 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row6_col2 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row6_col3 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row6_col4 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row6_col5 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row7_col0 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row7_col1 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row7_col2 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row7_col3 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row7_col4 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row8_col0 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row8_col1 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row8_col2 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row8_col3 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row8_col4 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row9_col0 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row9_col1 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row9_col2 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row9_col3 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row9_col4 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row10_col0 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row10_col1 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row10_col2 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row10_col3 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row10_col4 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row11_col1 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row11_col2 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row11_col4 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row11_col5 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row12_col0 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row12_col2 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row12_col3 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row12_col4 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row13_col1 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row13_col3 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row13_col5 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row14_col0 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row14_col1 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row14_col2 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row14_col4 {
#             background:  green;
#             : ;
#         }    #T_8b165ff8_14df_11ed_877b_acde48001122row15_col1 {
#             background:  green;
#             : ;
#         }

# %% [markdown]
# # Drop Types

# %%
#DROP EXTRA COLUMNS (INCLUDING TYPES)
stats=df.drop(['TYPE1'],axis=1).drop(['TYPE2'],axis=1).drop(['ABILITY1'],axis=1).drop(['ABILITY2'],axis=1).drop(['ABILITY3'],axis=1) #drop the columns with axis=1;axis=0 is for rows

# %%
spd = stats.sort_values(by='SPD', ascending=False).head(10) #order by biggest total at top
spd.style.apply(lambda x: ["background: green" if((i==0 and v >= 95) or (i==1 and v>=110) or (i==2 and v>=90) or (i==3 and v>99) or (i==4 and v>=90) or (i==5 and v>100)) else "" for i, v in enumerate(x)], axis = 1).apply(lambda x: ["background: red" if((i==0 and v <= 70) or (i==1 and v<=75) or (i==2 and v<=65) or (i==3 and v<=60) or (i==4 and v<63) or (i==5 and v<55)) else "" for i, v in enumerate(x)], axis=1)
# Out:
# <style  type="text/css" >
#     #T_8b1fb63e_14df_11ed_877b_acde48001122row0_col2 {
#             : ;
#             background:  red;
#         }    #T_8b1fb63e_14df_11ed_877b_acde48001122row0_col3 {
#             background:  green;
#             : ;
#         }    #T_8b1fb63e_14df_11ed_877b_acde48001122row0_col4 {
#             : ;
#             background:  red;
#         }    #T_8b1fb63e_14df_11ed_877b_acde48001122row0_col5 {
#             background:  green;
#             : ;
#         }    #T_8b1fb63e_14df_11ed_877b_acde48001122row1_col0 {
#             : ;
#             background:  red;
#         }    #T_8b1fb63e_14df_11ed_877b_acde48001122row1_col2 {
#             : ;
#             background:  red;
#         }    #T_8b1fb63e_14df_11ed_877b_acde48001122row1_col3 {
#             : ;
#             background:  red;
#         }    #T_8b1fb63e_14df_11ed_877b_acde48001122row1_col4 {
#             : ;
#             background:  red;
#         }    #T_8b1fb63e_14df_11ed_877b_acde48001122row1_col5 {
#             background:  green;
#             : ;
#         }    #T_8b1fb63e_14df_11ed_877b_acde48001122row2_col1 {
#             background:  green;
#             : ;
#         }    #T_8b1fb63e_14df_11ed_877b_acde48001122row2_col2 {
#             : ;
#             background:  red;
#         }    #T_8b1fb63e_14df_11ed_877b_acde48001122row2_col3 {
#             background:  green;
#             : ;
#         }    #T_8b1fb63e_14df_11ed_877b_acde48001122row2_col4 {
#             : ;
#             background:  red;
#         }    #T_8b1fb63e_14df_11ed_877b_acde48001122row2_col5 {
#             background:  green;
#             : ;
#         }    #T_8b1fb63e_14df_11ed_877b_acde48001122row3_col0 {
#             : ;
#             background:  red;
#         }    #T_8b1fb63e_14df_11ed_877b_acde48001122row3_col1 {
#             : ;
#             background:  red;
#         }    #T_8b1fb63e_14df_11ed_877b_acde48001122row3_col5 {
#             background:  green;
#             : ;
#         }    #T_8b1fb63e_14df_11ed_877b_acde48001122row4_col0 {
#             : ;
#             background:  red;
#         }    #T_8b1fb63e_14df_11ed_877b_acde48001122row4_col1 {
#             background:  green;
#             : ;
#         }    #T_8b1fb63e_14df_11ed_877b_acde48001122row4_col2 {
#             : ;
#             background:  red;
#         }    #T_8b1fb63e_14df_11ed_877b_acde48001122row4_col3 {
#             background:  green;
#             : ;
#         }    #T_8b1fb63e_14df_11ed_877b_acde48001122row4_col4 {
#             : ;
#             background:  red;
#         }    #T_8b1fb63e_14df_11ed_877b_acde48001122row4_col5 {
#             background:  green;
#             : ;
#         }    #T_8b1fb63e_14df_11ed_877b_acde48001122row5_col1 {
#             : ;
#             background:  red;
#         }    #T_8b1fb63e_14df_11ed_877b_acde48001122row5_col2 {
#             : ;
#             background:  red;
#         }    #T_8b1fb63e_14df_11ed_877b_acde48001122row5_col3 {
#             background:  green;
#             : ;
#         }    #T_8b1fb63e_14df_11ed_877b_acde48001122row5_col4 {
#             : ;
#             background:  red;
#         }    #T_8b1fb63e_14df_11ed_877b_acde48001122row5_col5 {
#             background:  green;
#             : ;
#         }    #T_8b1fb63e_14df_11ed_877b_acde48001122row6_col1 {
#             background:  green;
#             : ;
#         }    #T_8b1fb63e_14df_11ed_877b_acde48001122row6_col3 {
#             background:  green;
#             : ;
#         }    #T_8b1fb63e_14df_11ed_877b_acde48001122row6_col5 {
#             background:  green;
#             : ;
#         }    #T_8b1fb63e_14df_11ed_877b_acde48001122row7_col1 {
#             background:  green;
#             : ;
#         }    #T_8b1fb63e_14df_11ed_877b_acde48001122row7_col3 {
#             background:  green;
#             : ;
#         }    #T_8b1fb63e_14df_11ed_877b_acde48001122row7_col5 {
#             background:  green;
#             : ;
#         }    #T_8b1fb63e_14df_11ed_877b_acde48001122row8_col1 {
#             background:  green;
#             : ;
#         }    #T_8b1fb63e_14df_11ed_877b_acde48001122row8_col2 {
#             background:  green;
#             : ;
#         }    #T_8b1fb63e_14df_11ed_877b_acde48001122row8_col4 {
#             background:  green;
#             : ;
#         }    #T_8b1fb63e_14df_11ed_877b_acde48001122row8_col5 {
#             background:  green;
#             : ;
#         }    #T_8b1fb63e_14df_11ed_877b_acde48001122row9_col1 {
#             background:  green;
#             : ;
#         }    #T_8b1fb63e_14df_11ed_877b_acde48001122row9_col2 {
#             background:  green;
#             : ;
#         }    #T_8b1fb63e_14df_11ed_877b_acde48001122row9_col4 {
#             background:  green;
#             : ;
#         }    #T_8b1fb63e_14df_11ed_877b_acde48001122row9_col5 {
#             background:  green;
#             : ;
#         }</style><table id="T_8b1fb63e_14df_11ed_877b_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >HP</th>        <th class="col_heading level0 col1" >ATK</th>        <th class="col_heading level0 col2" >DEF</th>        <th class="col_heading level0 col3" >SPATK</th>        <th class="col_heading level0 col4" >SPDEF</th>        <th class="col_heading level0 col5" >SPD</th>        <th class="col_heading level0 col6" >TOTAL</th>    </tr>    <tr>        <th class="index_name level0" >NAME</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8b1fb63e_14df_11ed_877b_acde48001122level0_row0" class="row_heading level0 row0" >Regieleki</th>
#                         <td id="T_8b1fb63e_14df_11ed_877b_acde48001122row0_col0" class="data row0 col0" >80</td>
#                         <td id="T_8b1fb63e_14df_11ed_877b_acde48001122row0_col1" class="data row0 col1" >100</td>
#                         <td id="T_8b1fb63e_14df_11ed_877b_acde48001122row0_col2" class="data row0 col2" >50</td>
#                         <td id="T_8b1fb63e_14df_11ed_877b_acde48001122row0_col3" class="data row0 col3" >100</td>
#                         <td id="T_8b1fb63e_14df_11ed_877b_acde48001122row0_col4" class="data row0 col4" >50</td>
#                         <td id="T_8b1fb63e_14df_11ed_877b_acde48001122row0_col5" class="data row0 col5" >200</td>
#                         <td id="T_8b1fb63e_14df_11ed_877b_acde48001122row0_col6" class="data row0 col6" >580</td>
#             </tr>
#             <tr>
#                         <th id="T_8b1fb63e_14df_11ed_877b_acde48001122level0_row1" class="row_heading level0 row1" >Ninjask</th>
#                         <td id="T_8b1fb63e_14df_11ed_877b_acde48001122row1_col0" class="data row1 col0" >61</td>
#                         <td id="T_8b1fb63e_14df_11ed_877b_acde48001122row1_col1" class="data row1 col1" >90</td>
#                         <td id="T_8b1fb63e_14df_11ed_877b_acde48001122row1_col2" class="data row1 col2" >45</td>
#                         <td id="T_8b1fb63e_14df_11ed_877b_acde48001122row1_col3" class="data row1 col3" >50</td>
#                         <td id="T_8b1fb63e_14df_11ed_877b_acde48001122row1_col4" class="data row1 col4" >50</td>
#                         <td id="T_8b1fb63e_14df_11ed_877b_acde48001122row1_col5" class="data row1 col5" >160</td>
#                         <td id="T_8b1fb63e_14df_11ed_877b_acde48001122row1_col6" class="data row1 col6" >456</td>
#             </tr>
#             <tr>
#                         <th id="T_8b1fb63e_14df_11ed_877b_acde48001122level0_row2" class="row_heading level0 row2" >Pheromosa</th>
#                         <td id="T_8b1fb63e_14df_11ed_877b_acde48001122row2_col0" class="data row2 col0" >71</td>
#                         <td id="T_8b1fb63e_14df_11ed_877b_acde48001122row2_col1" class="data row2 col1" >137</td>
#                         <td id="T_8b1fb63e_14df_11ed_877b_acde48001122row2_col2" class="data row2 col2" >37</td>
#                         <td id="T_8b1fb63e_14df_11ed_877b_acde48001122row2_col3" class="

# %%
print(sum(stats['TOTAL'] >= 500), sum(stats['TOTAL'] >= 525)) #number of pokemon with base totals >=500 and >=525
# Out:
# 254 165

# %%
#gen5_noL[gen5_noL['TOTAL'] >= 500] #all pokemon with total of 500 plus
stats[stats['TOTAL'] >= 500].style.apply(lambda x: ["background: green" if((i==0 and v >= 95) or (i==1 and v>=110) or (i==2 and v>=90) or (i==3 and v>99) or (i==4 and v>=90) or (i==5 and v>100)) else "" for i, v in enumerate(x)], axis = 1).apply(lambda x: ["background: red" if((i==0 and v <= 70) or (i==1 and v<=75) or (i==2 and v<=65) or (i==3 and v<=60) or (i==4 and v<63) or (i==5 and v<55)) else "" for i, v in enumerate(x)], axis=1)
# Out:
# <style  type="text/css" >
#     #T_8ba3d34c_14df_11ed_877b_acde48001122row0_col0 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row0_col1 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row0_col2 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row0_col3 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row0_col4 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row0_col5 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row1_col0 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row1_col2 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row1_col3 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row1_col4 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row1_col5 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row2_col0 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row2_col1 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row2_col2 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row2_col3 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row2_col4 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row3_col0 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row3_col2 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row3_col3 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row3_col4 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row4_col1 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row4_col2 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row4_col3 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row4_col4 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row5_col0 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row5_col1 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row5_col2 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row5_col3 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row5_col4 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row6_col0 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row6_col1 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row6_col2 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row6_col3 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row6_col4 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row6_col5 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row7_col0 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row7_col1 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row7_col2 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row7_col3 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row7_col4 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row8_col0 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row8_col1 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row8_col2 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row8_col3 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row8_col4 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row9_col0 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row9_col1 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row9_col2 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row9_col3 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row9_col4 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row10_col0 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row10_col1 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row10_col2 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row10_col3 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row11_col0 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row11_col1 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row11_col2 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row11_col3 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row11_col4 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row12_col0 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row12_col2 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row12_col4 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row12_col5 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row13_col0 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row13_col1 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row13_col3 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row13_col4 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row14_col0 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row14_col1 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row14_col2 {
#             background:  green;
#             : ;
#         }    #T_8ba3d34c_14df_11ed_877b_acde48001122row14_col3 {
#             background:  green;
#             : ;
#         }

# %%
#needs to be written
def type_weakness(type1,type2):
    if type1 == 'normal':
        if type2 in ['rock' ,'steel']:
            return 0.5
        elif type2 == 'ghost':
            return 0
    if type1 == 'fire':
        if type2 in ['water','fire','rock', 'dragon']:
            return 0.5
        elif type2 in ['grass', 'ice', 'bug','steel']:
            return 2
    if type1 == 'water':
        if type2 in ['water', 'grass', 'dragon']:
            return 0.5
        if type2 in ['fire', 'ground', 'rock']:
            return 2
    if type1 == 'grass':
        if type2 in ['fire', 'grass', 'poison' , 'dragon', 'steel', 'bug', 'flying']:
            return 0.5
        if type2 in ['water' , 'ground' ,'rock']:
            return 2
    if type1 == 'electric':
        if type2 == 'ground':
            return 0
        if type2 in ['grass', 'electric', 'dragon']:
            return 0.5
        if type2 in ['water','flying']:
            return 2
    if type1 == 'ice':
        if type2 in ['fire', 'water', 'ice', 'steel']:
            return 0.5
        if type2 in ['grass','flying','ground', 'dragon']:
            return 2
    if type1 == 'fighting':
        if type2 == 'ghost':
            return 0
        if type2 in ['poison', 'flying', 'psychic', 'bug', 'fairy']:
            return 0.5
        if type2 in ['normal', 'ice','rock', 'dark', 'steel']:
            return 2
    if type1 == 'poison':
        if type2 == 'steel':
            return 0
        if type2 in ['poison', 'ground', 'rock', 'ghost']:
            return 0.5
        if type2 in['fairy', 'grass']:
            return 2
    if type1 == 'ground':
        if type2 == 'flying':
            return 0
        if type2 in['grass','bug']:
            return 0.5
        if type2 in ['fire', 'electric','rock', 'steel', 'poison']:
            return 2
    if type1 == 'flying':
        if type2 in['electric','steel', 'rock']:
            return 0.5
        if type2 in ['grass', 'fighting', 'bug']:
            return 2
    if type1 == 'psychic':
        if type2 == 'dark':
            return 0
        if type2 in['steel','psychic']:
            return 0.5
        if type2 in ['fighting', 'poison']:
            return 2
    if type1 == 'bug':
        if type2 in ['fire', 'fighting', 'poison', 'flying', 'ghost' ,'steel', 'fairy']:
            return 0.5
        if type2 in ['dark','psychic','ghost']:
            return 2
    if type1 == 'rock':
        if type2 in ['steel', 'fighting', 'ground']:
            return 0.5
        if type2 in ['bug' ,'flying','ice','fire']:
            return 2
    if type1 == 'ghost':
        if type2 == 'normal':
            return 0
        if type2 == 'dark':
            return 0.5
        if type2 in ['psychic','ghost']:
            return 2
    if type1 == 'dragon':
        if type2 == 'fairy':
            return 0
        if type2 == 'steel':
            return 0.5
        if type2 == 'dragon':
            return 2
    if type1 == 'dark':
        if type2 in ['fighting','dark','fairy']:
            return 0.5
        if type2 in ['ghost','psychic']:
            return 2
    if type1 == 'steel':
        if type2 in ['steel','fire','water','electric']:
            return 0.5
        if type2 in ['ice','rock','fairy']:
            return 2
    if type1 == 'fairy':
        if type2 in ['fire', 'poison', 'steel']:
            return 0.5
        if type2 in ['dragon', 'fighting', 'dark']:
            return 2
    return 1

# %%
def gen1_dmg(attack, defence, lvl, crit, power, movetype, physical,stab,deftype1,deftype2):
    #initial dmg
    dmg = 2*lvl
    #if crits
    if crit == True:
        dmg = 2*dmg
    #extras
    dmg = dmg/5 + 2
    #move power
    dmg = dmg*power
    #Physical or Special dmg
    dmg = dmg*attack/defence
    #extras
    dmg =dmg/50+2
    #STAB dmg
    if stab == True:
        dmg = dmg*1.5
    #consider weaknesses
    if deftype1 == deftype2:
        dmg = dmg*type_weakness(movetype,deftype1)
    else:
        dmg = dmg*type_weakness(movetype,deftype1)*type_weakness(movetype,deftype2)
    return [int(dmg*(217/255)),int(dmg)]

# %%
gen1_dmg(attack=27,defence=16,lvl=15,crit=True,power=40,movetype='normal',physical=True,stab=True,deftype1='normal',deftype2='normal')
# Out:
# [26, 31]

# %%
def gen2_dmg(attack, defence, lvl, crit, power, movetype, physical,stab,deftype1,deftype2,item,badge,weather):
    #initial dmg
    dmg = 2*lvl/5+2
    #move power
    dmg = dmg*power
    #Physical or Special dmg
    dmg = dmg*attack/defence
    #extras
    dmg =dmg/50
    #if crits
    if crit == True:
        dmg = 2*dmg
    #item multiplier
    dmg = dmg*item
    #extras
    dmg = dmg+2
    #STAB dmg
    if stab == True:
        dmg = dmg*1.5
    #badge
    dmg = dmg*badge
    #weather
    if weather == True:
        dmg = dmg*1.5
    #consider weaknesses
    if deftype1 == deftype2:
        dmg = dmg*type_weakness(movetype,deftype1)
    else:
        dmg = dmg*type_weakness(movetype,deftype1)*type_weakness(movetype,deftype2)
    
    return [int(dmg*(217/255)),int(dmg)]

# %%
gen2_dmg(attack=27,defence=16,lvl=15,crit=True,power=40,movetype='normal',physical=True,stab=True,deftype1='normal',deftype2='normal',item=1,badge=1,weather=False)
# Out:
# [30, 35]

# %%
def gen3_dmg(attack, defence, lvl, crit, power, movetype, physical,stab,deftype1,deftype2,item,weather,burn,screen,double,targetall,FF,WBR,HH,charge):
    #initial dmg
    dmg = 2*lvl/5+2
    #move power
    dmg = dmg*power
    #Physical or Special dmg
    dmg = dmg*attack/defence
    #extras
    dmg =dmg/50
    #burned (and not guts)
    if burn == True:
        dmg = dmg/2
    #screen
    if screen == True:
        if double == True:
            dmg = dmg*2/3
        else:
            dmg = dmg/2
    #in double battle dmg split between targets
    if double == True and targetall == False:
        dmg = dmg/2
    #flash fire
    if FF == True:
        dmg = dmg*1.5
    #weather
    if weather == True:
        dmg = dmg*1.5
    #extras
    dmg = dmg+2
    #item multiplier (assuming this goes here)
    dmg = dmg*item
    #extras
    dmg = dmg+2
    #STAB dmg
    if stab == True:
        dmg = dmg*1.5
    #consider weaknesses
    if deftype1 == deftype2:
        dmg = dmg*type_weakness(movetype,deftype1)
    else:
        dmg = dmg*type_weakness(movetype,deftype1)*type_weakness(movetype,deftype2)
    #if crits
    if crit == True:
        dmg = 2*dmg
    #weatherball revenge (only in clear weather)
    if WBR == True:
        dmg = dmg*2
    #helping hand
    if HH == True:
        dmg = dmg*1.5
    #electric type charge effect
    if charge == True:
        dmg =dmg*2
    return [int(dmg*(85/100)),int(dmg)]

# %%
gen3_dmg(attack=27,defence=16,lvl=15,crit=True,power=40,movetype='normal',physical=True,stab=True,deftype1='normal',deftype2='normal',item=1,weather=False,burn=False,screen=False,double=False,targetall=False,FF=False,WBR=False,HH=False,charge=False)
# Out:
# [37, 44]

# %%
def gen4_dmg(attack, defence, lvl, crit, power, movetype, physical,stab,deftype1,deftype2,item,weather,burn,screen,double,targetall,FF,WBR,HH,charge,other):
    #initial dmg
    dmg = 2*lvl/5+2
    #move power
    dmg = dmg*power
    #Physical or Special dmg
    dmg = dmg*attack/defence
    #extras
    dmg =dmg/50
    #burned (and not guts)
    if burn == True:
        dmg = dmg/2
    #screen
    if screen == True:
        if double == True:
            dmg = dmg*2/3
        else:
            dmg = dmg/2
    #in double battle dmg split between targets
    if double == True and targetall == False:
        dmg = dmg/2
    #flash fire
    if FF == True:
        dmg = dmg*1.5
    #weather
    if weather == True:
        dmg = dmg*1.5
    #extras
    dmg = dmg+2
    #item multiplier (assuming this goes here)
    dmg = dmg*item
    #extras
    dmg = dmg+2
    #STAB dmg
    if stab == True:
        dmg = dmg*1.5
    #consider weaknesses
    if deftype1 == deftype2:
        dmg = dmg*type_weakness(movetype,deftype1)
    else:
        dmg = dmg*type_weakness(movetype,deftype1)*type_weakness(movetype,deftype2)
    #if crits
    if crit == True:
        dmg = 2*dmg
    #weatherball revenge (only in clear weather)
    if WBR == True:
        dmg = dmg*2
    #helping hand
    if HH == True:
        dmg = dmg*1.5
    #electric type charge effect
    if charge == True:
        dmg =dmg*2
    #any other abilities and effects
    dmg = dmg*other
    return [int(dmg*(85/100)),int(dmg)]

# %%
gen5_up_dmg(attack=27,defence=16,lvl=15,crit=True,power=40,movetype='normal',physical=True,stab=True,deftype1='normal',deftype2='normal',item=1,weather=False,burn=False,screen=False,double=False,targetall=False,FF=False,WBR=False,HH=False,charge=False,other=1)
# Out:
# [37, 44]

# %%
def gen5_up_dmg(attack, defence, lvl, crit, power, movetype, physical,stab,deftype1,deftype2,item,weather,burn,screen,double,targetall,FF,WBR,HH,charge,other):
    #initial dmg
    dmg = 2*lvl/5+2
    #move power
    dmg = dmg*power
    #Physical or Special dmg
    dmg = dmg*attack/defence
    #extras
    dmg =dmg/50+2
    #burned (and not guts)
    if burn == True:
        dmg = dmg/2
    #screen
    if screen == True:
        if double == True:
            dmg = dmg*2/3
        else:
            dmg = dmg/2
    #in double battle dmg split between targets
    if double == True and targetall == False:
        dmg = dmg/2
    #flash fire
    if FF == True:
        dmg = dmg*1.5
    #weather
    if weather == True:
        dmg = dmg*1.5
    #item multiplier (assuming this goes here)
    dmg = dmg*item
    #extras
    dmg = dmg+2
    #STAB dmg
    if stab == True:
        dmg = dmg*1.5
    #consider weaknesses
    if deftype1 == deftype2:
        dmg = dmg*type_weakness(movetype,deftype1)
    else:
        dmg = dmg*type_weakness(movetype,deftype1)
        dmg = dmg*type_weakness(movetype,deftype2)
    #if crits
    if crit == True:
        dmg = 2*dmg
    #weatherball revenge (only in clear weather)
    if WBR == True:
        dmg = dmg*2
    #helping hand
    if HH == True:
        dmg = dmg*1.5
    #electric type charge effect
    if charge == True:
        dmg =dmg*2
    #any other effects; e.g. abilities
    dmg = dmg*other
    return [int(dmg*(85/100)),int(dmg)]

# %%
gen5_up_dmg(attack=27,defence=16,lvl=15,crit=True,power=40,movetype='fairy',physical=True,stab=False,deftype1='dark',deftype2='dragon',item=1,weather=False,burn=False,screen=False,double=False,targetall=False,FF=False,WBR=False,HH=False,charge=False,other=1)
# Out:
# [100, 118]

# %%
type_weakness('fairy','dark')
# Out:
# 2

# %%
def base_stats_at_lvl(Pokemon,level):
    pkm = df[df.index == Pokemon]
    IV = 0#[0,0,0,0,0,0]
    EV = 0#[0,0,0,0,0,0]
    HP = ((2*pkm['HP']+IV+(EV/4))*level)/100+level+10
    ATK = ((2*pkm['ATK']+IV+(EV/4))*level)/100+5
    DEF = ((2*pkm['DEF']+IV+(EV/4))*level)/100+5
    SPATK = ((2*pkm['SPATK']+IV+(EV/4))*level)/100+5
    SPDEF = ((2*pkm['SPDEF']+IV+(EV/4))*level)/100+5
    SPD = ((2*pkm['SPD']+IV+(EV/4))*level)/100+5
    return [int(HP),int(ATK),int(DEF),int(SPATK),int(SPDEF),int(SPD)]

# %%
base_stats_at_lvl('Patrat',15)
# Out:
# [38, 21, 16, 15, 16, 17]

# %%
def phys_spec_ratio(atk_pkm,atk_lvl,def_pkm,def_lvl):
    pkm1 = base_stats_at_lvl(atk_pkm,atk_lvl)
    pkm2 = base_stats_at_lvl(def_pkm,def_lvl)
    phys = pkm1[1]/pkm2[2]
    spec = pkm1[3]/pkm2[4]
    return[float(phys),float(spec)]

# %%
phys_spec_ratio('Patrat',15,'Patrat',15)
# Out:
# [1.3125, 0.9375]
